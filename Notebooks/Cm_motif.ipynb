# %%
import numpy as np
import modisco
from importlib import reload
from collections import OrderedDict

import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = '../results/Cm/'

task_to_scores = OrderedDict()
task_to_hyp_scores = OrderedDict()
task_to_scores['Cm'] = np.load(data_dir + 'shuffle_task_to_scores.npy', allow_pickle=True)
task_to_hyp_scores['Cm'] = np.load(data_dir + 'shuffle_task_to_hyp_scores.npy', allow_pickle=True)
onehot_data = np.load(data_dir + 'shuffle_onehot_data.npy', allow_pickle=True)

# %%
import modisco.visualization
from modisco.visualization import viz_sequence

viz_sequence.plot_weights(task_to_scores['Cm'][1], subticks_frequency=5)
viz_sequence.plot_weights(task_to_hyp_scores['Cm'][1], subticks_frequency=5)
viz_sequence.plot_weights(onehot_data[1], subticks_frequency=5)

# %%
null_per_pos_scores = modisco.coordproducers.LaplaceNullDist(num_to_samp=5000)
tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                    #Slight modifications from the default settings
                    sliding_window_size=7,
                    flank_size=3,
                    target_seqlet_fdr=0.01,
                    seqlets_to_patterns_factory=
                     modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                        trim_to_window_size=7,
                        initial_flank_to_add=3,
                        kmer_len=8, num_gaps=3,
                        num_mismatches=2,
                        final_min_cluster_size=20)
                )(
                 task_names=["Cm"],
                 contrib_scores=task_to_scores,
                 hypothetical_contribs=task_to_hyp_scores,
                 one_hot=onehot_data,
                 null_per_pos_scores = null_per_pos_scores,
                 revcomp=False
)
# Out:
# MEMORY 0.388939776
# On task Cm
# Computing windowed sums on original
# Generating null dist
# peak(mu)= -0.0018144439160823823
# Computing threshold
# For increasing = True , the minimum IR precision was 0.32649817199173425 occurring at 3.2708048820495605e-06 implying a frac_neg of 0.4847769648336087
# To be conservative, adjusted frac neg is 0.95
# For increasing = False , the minimum IR precision was 0.42463212563373326 occurring at -4.4405460357666016e-06 implying a frac_neg of 0.7380184826993342
# To be conservative, adjusted frac neg is 0.95
# Thresholds from null dist were -0.27263206243515015  and  0.4917672574520111 with frac passing 0.020286632073140597
# Passing windows frac was 0.020286632073140597 , which is below  0.03 ; adjusting
# Final raw thresholds are -0.4140894633531571  and  0.4140894633531571
# Final transformed thresholds are -0.9699777613046702  and  0.9699777613046702
# Got 290 coords
# After resolving overlaps, got 290 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.9698777613046702
# MEMORY 0.378847232
# 290 identified in total
# 1 activity patterns with support >= 100 out of 2 possible patterns
# Metacluster sizes:  [282]
# Idx to activities:  {0: '1'}
# MEMORY 0.378847232
# On metacluster 0
# Metacluster size 282
# Relevant tasks:  ('Cm',)
# Relevant signs:  (1,)
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 282
# (Round 1) Computing coarse affmat
# MEMORY 0.420777984
# Beginning embedding computation
# MEMORY 0.420777984
# Computing embeddings
# Finished embedding computation in 0.84 s
# MEMORY 0.588722176
# Starting affinity matrix computations
# MEMORY 0.588722176
# Batching in slices of size 282
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 16.59it/s]
# Finished affinity matrix computations in 0.15 s
# MEMORY 0.620351488
# (Round 1) Computed coarse affmat
# MEMORY 0.613453824
# (Round 1) Computing affinity matrix on nearest neighbors
# MEMORY 0.613453824
# Launching nearest neighbors affmat calculation job
# MEMORY 0.613691392
# Parallel runs completed
# MEMORY 0.43360256
# Job completed in: 0.5 s
# MEMORY 0.43360256
# (Round 1) Computed affinity matrix on nearest neighbors in 0.64 s
# MEMORY 0.4337664
# Filtered down to 282 of 282
# (Round 1) Retained 282 rows out of 282 after filtering
# MEMORY 0.4337664
# (Round 1) Computing density adapted affmat
# MEMORY 0.4337664
# Symmetrizing nearest neighbors
# Computing betas for density adaptation
# Computing normalizing denominators
# (Round 1) Computing clustering
# MEMORY 0.443994112
# Beginning preprocessing + Leiden
# Affmat shape: 282
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.1s
# Quality: 0.02432696212984677
# Got 3 clusters after round 1
# Counts:
# {1: 93, 0: 100, 2: 89}
# MEMORY 0.44423168
# (Round 1) Aggregating seqlets in each cluster
# MEMORY 0.44423168
# Aggregating for cluster 0 with 100 seqlets
# MEMORY 0.44423168
# Trimming eliminated 0 seqlets out of 100
# Aggregating for cluster 1 with 93 seqlets
# MEMORY 0.44423168
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    4.8s finished
# Trimming eliminated 0 seqlets out of 93
# Aggregating for cluster 2 with 89 seqlets
# MEMORY 0.44423168
# Trimming eliminated 0 seqlets out of 89
# (Round 2) num seqlets: 282
# (Round 2) Computing coarse affmat
# MEMORY 0.440967168
# Beginning embedding computation
# MEMORY 0.440967168
# Computing embeddings
# Finished embedding computation in 0.5 s
# MEMORY 0.588210176
# Starting affinity matrix computations
# MEMORY 0.588210176
# Batching in slices of size 282
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 21.24it/s]
# Finished affinity matrix computations in 0.13 s
# MEMORY 0.626696192
# (Round 2) Computed coarse affmat
# MEMORY 0.619798528
# (Round 2) Computing affinity matrix on nearest neighbors
# MEMORY 0.619798528
# Launching nearest neighbors affmat calculation job
# MEMORY 0.619917312
# Parallel runs completed
# MEMORY 0.43659264
# Job completed in: 0.39 s
# MEMORY 0.43659264
# (Round 2) Computed affinity matrix on nearest neighbors in 0.5 s
# MEMORY 0.43700224
# Not applying filtering for rounds above first round
# MEMORY 0.43700224
# (Round 2) Computing density adapted affmat
# MEMORY 0.437067776
# Symmetrizing nearest neighbors
# Computing betas for density adaptation
# Computing normalizing denominators
# (Round 2) Computing clustering
# MEMORY 0.451592192
# Beginning preprocessing + Leiden
# Affmat shape: 282
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.7s
# Quality: 0.022484510608416452
# Quality: 0.022573320951265536
# Got 4 clusters after round 2
# Counts:
# {1: 80, 3: 47, 2: 62, 0: 93}
# MEMORY 0.449396736
# (Round 2) Aggregating seqlets in each cluster
# MEMORY 0.449396736
# Aggregating for cluster 0 with 93 seqlets
# MEMORY 0.449396736
# Trimming eliminated 0 seqlets out of 93
# Aggregating for cluster 1 with 80 seqlets
# MEMORY 0.449396736
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    4.4s finished
# Trimming eliminated 0 seqlets out of 80
# Aggregating for cluster 2 with 62 seqlets
# MEMORY 0.449396736
# Trimming eliminated 0 seqlets out of 62
# Aggregating for cluster 3 with 47 seqlets
# MEMORY 0.449396736
# Trimming eliminated 0 seqlets out of 47
# Got 4 clusters
# Splitting into subclusters...
# MEMORY 0.449396736
# Inspecting pattern 0 for spurious merging
# [t-SNE] Computed conditional probabilities for sample 93 / 93
# [t-SNE] Mean sigma: 0.499965
# Beginning preprocessing + Leiden
# Affmat shape: 93
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  93 out of  93 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.7s
# Quality: 0.19452960917380804
# Got subclusters: Counter({0: 27, 1: 21, 2: 20, 3: 16, 4: 9})
# On merging iteration 1
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.1s finished
# Numbers for each pattern pre-subsample: [27, 21, 20, 16, 9]
# Numbers after subsampling: [27, 21, 20, 16, 9]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.13698911666870117 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.12284708023071289 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.11203503608703613 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.08574175834655762 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.06606841087341309 s
# Cluster sizes
# [27 21 20 16  9]
# Cross-contamination matrix:
# [[1.   0.49 0.86 0.49 0.55]
#  [0.42 1.   0.76 0.45 0.43]
#  [0.37 0.4  1.   0.26 0.22]
#  [0.61 0.63 0.8  1.   0.54]
#  [0.48 0.45 0.52 0.39 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.8  0.89 0.85 0.76]
#  [0.8  1.   0.86 0.8  0.63]
#  [0.89 0.86 1.   0.84 0.79]
#  [0.85 0.8  0.84 1.   0.72]
#  [0.76 0.63 0.79 0.72 1.  ]]
# Inspecting pattern 1 for spurious merging
# [t-SNE] Computed conditional probabilities for sample 80 / 80
# [t-SNE] Mean sigma: 0.527078
# Beginning preprocessing + Leiden
# Affmat shape: 80
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  80 out of  80 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.9s
# Quality: 0.16909259928186957
# Quality: 0.16949283553241012
# Got subclusters: Counter({0: 30, 1: 23, 2: 21, 3: 6})
# On merging iteration 1
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.4s finished
# Numbers for each pattern pre-subsample: [30, 23, 21, 6]
# Numbers after subsampling: [30, 23, 21, 6]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.12406182289123535 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.1082911491394043 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.09162306785583496 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.03887009620666504 s
# Cluster sizes
# [30 23 21  6]
# Cross-contamination matrix:
# [[1.   0.39 0.32 0.22]
#  [0.77 1.   0.61 0.55]
#  [0.86 0.83 1.   0.61]
#  [0.52 0.52 0.4  1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.9  0.84 0.73]
#  [0.9  1.   0.86 0.79]
#  [0.84 0.86 1.   0.69]
#  [0.73 0.79 0.69 1.  ]]
# Collapsing 1 & 2 with crosscontam 0.6070440340186374 and sim 0.8631057235307842
# Trimming eliminated 0 seqlets out of 44
# Unmerged patterns remapping: OrderedDict([(0, 1), (3, 2)])
# Time spent on merging iteration: 0.07422327995300293
# On merging iteration 2
# Numbers for each pattern pre-subsample: [44, 30, 6]
# Numbers after subsampling: [44, 30, 6]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.09460306167602539 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.04024076461791992 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.01421809196472168 s
# Cluster sizes
# [44 30  6]
# Cross-contamination matrix:
# [[1.   0.97 0.72]
#  [0.36 1.   0.22]
#  [0.47 0.52 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.9  0.77]
#  [0.9  1.   0.73]
#  [0.77 0.73 1.  ]]
# Inspecting pattern 2 for spurious merging
# [t-SNE] Computed conditional probabilities for sample 62 / 62
# [t-SNE] Mean sigma: 0.680123
# Beginning preprocessing + Leiden
# Affmat shape: 62
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  62 out of  62 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.9s
# Quality: 0.102852612022571
# Quality: 0.10299942445498475
# Quality: 0.10399694382652089
# Got subclusters: Counter({0: 23, 1: 21, 2: 18})
# On merging iteration 1
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.4s finished
# Numbers for each pattern pre-subsample: [23, 21, 18]
# Numbers after subsampling: [23, 21, 18]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.08266901969909668 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.06211686134338379 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.054328203201293945 s
# Cluster sizes
# [23 21 18]
# Cross-contamination matrix:
# [[1.   0.57 0.44]
#  [0.72 1.   0.63]
#  [0.58 0.63 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.75 0.69]
#  [0.75 1.   0.84]
#  [0.69 0.84 1.  ]]
# Inspecting pattern 3 for spurious merging
# Merging on 12 clusters
# MEMORY 0.442023936
# On merging iteration 1
# Numbers for each pattern pre-subsample: [27, 21, 20, 16, 9, 44, 30, 6, 23, 21, 18, 47]
# Numbers after subsampling: [27, 21, 20, 16, 9, 44, 30, 6, 23, 21, 18, 47]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.3780629634857178 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.32059788703918457 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.37700510025024414 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.25291991233825684 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.17975592613220215 s
# Computing sims for pattern 5
# Computed sims for pattern 5 in 0.49236297607421875 s
# Computing sims for pattern 6
# Computed sims for pattern 6 in 0.42815303802490234 s
# Computing sims for pattern 7
# Computed sims for pattern 7 in 0.13654589653015137 s
# Computing sims for pattern 8
# Computed sims for pattern 8 in 0.36089015007019043 s
# Computing sims for pattern 9
# Computed sims for pattern 9 in 0.328646183013916 s
# Computing sims for pattern 10
# Computed sims for pattern 10 in 0.27927613258361816 s
# Computing sims for pattern 11
# Computed sims for pattern 11 in 0.5458359718322754 s
# Cluster sizes
# [27 21 20 16  9 44 30  6 23 21 18 47]
# Cross-contamination matrix:
# [[1.   0.49 0.86 0.49 0.55 0.47 0.18 0.17 0.32 0.6  0.53 0.36]
#  [0.42 1.   0.76 0.45 0.43 0.24 0.11 0.09 0.14 0.34 0.24 0.3 ]
#  [0.37 0.4  1.   0.26 0.22 0.24 0.07 0.07 0.07 0.26 0.29 0.28]
#  [0.61 0.63 0.8  1.   0.54 0.18 0.03 0.07 0.06 0.24 0.25 0.39]
#  [0.48 0.45 0.52 0.39 1.   0.34 0.18 0.21 0.2  0.37 0.45 0.49]
#  [0.46 0.27 0.59 0.13 0.35 1.   0.97 0.72 0.22 0.56 0.63 0.57]
#  [0.03 0.01 0.05 0.   0.02 0.36 1.   0.22 0.01 0.07 0.08 0.08]
#  [0.09 0.04 0.19 0.02 0.08 0.47 0.52 1.   0.25 0.25 0.31 0.36]
#  [0.2  0.1  0.2  0.01 0.09 0.14 0.03 0.26 1.   0.57 0.44 0.08]
#  [0.57 0.4  0.66 0.17 0.37 0.6  0.45 0.39 0.72 1.   0.63 0.38]
#  [0.49 0.28 0.67 0.18 0.44 0.59 0.34 0.42 0.58 0.63 1.   0.42]
#  [0.37 0.35 0.72 0.29 0.53 0.62 0.39 0.55 0.13 0.4  0.49 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.8  0.89 0.85 0.76 0.79 0.59 0.59 0.55 0.85 0.78 0.83]
#  [0.8  1.   0.86 0.8  0.63 0.63 0.48 0.42 0.44 0.79 0.64 0.71]
#  [0.89 0.86 1.   0.84 0.79 0.83 0.66 0.64 0.58 0.87 0.82 0.9 ]
#  [0.85 0.8  0.84 1.   0.72 0.57 0.36 0.46 0.51 0.74 0.63 0.76]
#  [0.76 0.63 0.79 0.72 1.   0.71 0.49 0.53 0.55 0.75 0.8  0.75]
#  [0.79 0.63 0.83 0.57 0.71 1.   0.9  0.77 0.58 0.81 0.84 0.85]
#  [0.59 0.48 0.66 0.36 0.49 0.9  1.   0.73 0.53 0.67 0.68 0.66]
#  [0.59 0.42 0.64 0.46 0.53 0.77 0.73 1.   0.49 0.64 0.69 0.75]
#  [0.55 0.44 0.58 0.51 0.55 0.58 0.53 0.49 1.   0.75 0.69 0.58]
#  [0.85 0.79 0.87 0.74 0.75 0.81 0.67 0.64 0.75 1.   0.84 0.83]
#  [0.78 0.64 0.82 0.63 0.8  0.84 0.68 0.69 0.69 0.84 1.   0.83]
#  [0.83 0.71 0.9  0.76 0.75 0.85 0.66 0.75 0.58 0.83 0.83 1.  ]]
# Collapsing 0 & 9 with crosscontam 0.5666614676440829 and sim 0.8532323757060863
# Collapsing 5 & 11 with crosscontam 0.5703178701024667 and sim 0.8517720135591736
# Trimming eliminated 0 seqlets out of 48
# Trimming eliminated 0 seqlets out of 91
# Unmerged patterns remapping: OrderedDict([(1, 4), (2, 5), (3, 7), (4, 8), (6, 2), (7, 9), (8, 3), (10, 6)])
# Time spent on merging iteration: 0.6499462127685547
# On merging iteration 2
# Numbers for each pattern pre-subsample: [91, 48, 30, 23, 21, 20, 18, 16, 9, 6]
# Numbers after subsampling: [91, 48, 30, 23, 21, 20, 18, 16, 9, 6]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.6068391799926758 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.4615652561187744 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.08491396903991699 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.07671999931335449 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.06653594970703125 s
# Computing sims for pattern 5
# Computed sims for pattern 5 in 0.06240701675415039 s
# Computing sims for pattern 6
# Computed sims for pattern 6 in 0.05667281150817871 s
# Computing sims for pattern 7
# Computed sims for pattern 7 in 0.0495610237121582 s
# Computing sims for pattern 8
# Computed sims for pattern 8 in 0.03902387619018555 s
# Computing sims for pattern 9
# Computed sims for pattern 9 in 0.03156614303588867 s
# Cluster sizes
# [91 48 30 23 21 20 18 16  9  6]
# Cross-contamination matrix:
# [[1.   0.63 0.88 0.41 0.48 0.87 0.75 0.33 0.6  0.84]
#  [0.65 1.   0.37 0.71 0.62 0.97 0.8  0.51 0.73 0.44]
#  [0.21 0.05 1.   0.01 0.01 0.05 0.08 0.   0.02 0.22]
#  [0.18 0.37 0.03 1.   0.1  0.2  0.44 0.01 0.09 0.26]
#  [0.27 0.39 0.11 0.14 1.   0.76 0.24 0.45 0.43 0.09]
#  [0.26 0.32 0.07 0.07 0.4  1.   0.29 0.26 0.22 0.07]
#  [0.51 0.55 0.34 0.58 0.28 0.67 1.   0.18 0.44 0.42]
#  [0.29 0.45 0.03 0.06 0.63 0.8  0.25 1.   0.54 0.07]
#  [0.41 0.43 0.18 0.2  0.45 0.52 0.45 0.39 1.   0.21]
#  [0.41 0.16 0.52 0.25 0.04 0.19 0.31 0.02 0.08 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.87 0.8  0.59 0.7  0.89 0.88 0.69 0.76 0.79]
#  [0.87 1.   0.64 0.65 0.81 0.91 0.85 0.83 0.8  0.63]
#  [0.8  0.64 1.   0.53 0.48 0.66 0.68 0.36 0.49 0.73]
#  [0.59 0.65 0.53 1.   0.44 0.58 0.69 0.51 0.55 0.49]
#  [0.7  0.81 0.48 0.44 1.   0.86 0.64 0.8  0.63 0.42]
#  [0.89 0.91 0.66 0.58 0.86 1.   0.82 0.84 0.79 0.64]
#  [0.88 0.85 0.68 0.69 0.64 0.82 1.   0.63 0.8  0.69]
#  [0.69 0.83 0.36 0.51 0.8  0.84 0.63 1.   0.72 0.46]
#  [0.76 0.8  0.49 0.55 0.63 0.79 0.8  0.72 1.   0.53]
#  [0.79 0.63 0.73 0.49 0.42 0.64 0.69 0.46 0.53 1.  ]]
# Collapsing 1 & 5 with crosscontam 0.3186979166666668 and sim 0.911734773637106
# Collapsing 0 & 6 with crosscontam 0.5065496917348771 and sim 0.8780671934294229
# Collapsing 0 & 1 with crosscontam 0.6296010373718379 and sim 0.8721933290810057
# Trimming eliminated 0 seqlets out of 68
# Trimming eliminated 0 seqlets out of 109
# Trimming eliminated 0 seqlets out of 177
# Unmerged patterns remapping: OrderedDict([(2, 1), (3, 2), (4, 3), (7, 4), (8, 5), (9, 6)])
# Time spent on merging iteration: 0.37273693084716797
# On merging iteration 3
# Numbers for each pattern pre-subsample: [177, 30, 23, 21, 16, 9, 6]
# Numbers after subsampling: [177, 30, 23, 21, 16, 9, 6]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 1.0645208358764648 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.05535292625427246 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.046382904052734375 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.04114031791687012 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.03501391410827637 s
# Computing sims for pattern 5
# Computed sims for pattern 5 in 0.027530908584594727 s
# Computing sims for pattern 6
# Computed sims for pattern 6 in 0.024527788162231445 s
# Cluster sizes
# [177  30  23  21  16   9   6]
# Cross-contamination matrix:
# [[1.   0.81 0.64 0.72 0.54 0.78 0.81]
#  [0.14 1.   0.01 0.01 0.   0.02 0.22]
#  [0.25 0.03 1.   0.1  0.01 0.09 0.26]
#  [0.35 0.11 0.14 1.   0.45 0.43 0.09]
#  [0.39 0.03 0.06 0.63 1.   0.54 0.07]
#  [0.44 0.18 0.2  0.45 0.39 1.   0.21]
#  [0.31 0.52 0.25 0.04 0.02 0.08 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.75 0.63 0.78 0.77 0.81 0.76]
#  [0.75 1.   0.53 0.48 0.36 0.49 0.73]
#  [0.63 0.53 1.   0.44 0.51 0.55 0.49]
#  [0.78 0.48 0.44 1.   0.8  0.63 0.42]
#  [0.77 0.36 0.51 0.8  1.   0.72 0.46]
#  [0.81 0.49 0.55 0.63 0.72 1.   0.53]
#  [0.76 0.73 0.49 0.42 0.46 0.53 1.  ]]
# Got 7 patterns after merging
# MEMORY 0.442073088
# Performing filtering
# MEMORY 0.442073088
# Got 4 patterns after filtering
# MEMORY 0.442073088
# Total time taken is 34.59s
# MEMORY 0.442073088
# Applying subclustering to the final motifs
# On pattern 0
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 177 samples in 0.002s...
# [t-SNE] Computed neighbors for 177 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 177 / 177
# [t-SNE] Mean sigma: 0.412821
# [t-SNE] Computed conditional probabilities in 0.008s
# [t-SNE] Iteration 50: error = 56.0030518, gradient norm = 0.5886140 (50 iterations in 0.038s)
# [t-SNE] Iteration 100: error = 59.3737869, gradient norm = 0.5290068 (50 iterations in 0.029s)
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 130 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 177 out of 177 | elapsed:    0.1s finished
# [t-SNE] Iteration 150: error = 56.9704132, gradient norm = 0.5332560 (50 iterations in 0.041s)
# [t-SNE] Iteration 200: error = 57.8716660, gradient norm = 0.5579622 (50 iterations in 0.029s)
# [t-SNE] Iteration 250: error = 57.5310745, gradient norm = 0.5091419 (50 iterations in 0.025s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.531075
# [t-SNE] Iteration 300: error = 0.8596454, gradient norm = 0.0109714 (50 iterations in 0.026s)
# [t-SNE] Iteration 350: error = 0.7042969, gradient norm = 0.0020283 (50 iterations in 0.027s)
# [t-SNE] Iteration 400: error = 0.6849059, gradient norm = 0.0029369 (50 iterations in 0.026s)
# [t-SNE] Iteration 450: error = 0.6836300, gradient norm = 0.0003216 (50 iterations in 0.024s)
# [t-SNE] Iteration 500: error = 0.6839021, gradient norm = 0.0002345 (50 iterations in 0.030s)
# [t-SNE] Iteration 550: error = 0.6839349, gradient norm = 0.0002098 (50 iterations in 0.030s)
# [t-SNE] Iteration 600: error = 0.6837412, gradient norm = 0.0002169 (50 iterations in 0.023s)
# [t-SNE] Iteration 650: error = 0.6836085, gradient norm = 0.0002244 (50 iterations in 0.022s)
# [t-SNE] Iteration 700: error = 0.6838850, gradient norm = 0.0002881 (50 iterations in 0.024s)
# [t-SNE] Iteration 750: error = 0.6839967, gradient norm = 0.0002863 (50 iterations in 0.023s)
# [t-SNE] Iteration 800: error = 0.6837301, gradient norm = 0.0001623 (50 iterations in 0.025s)
# [t-SNE] Iteration 850: error = 0.6839046, gradient norm = 0.0002474 (50 iterations in 0.025s)
# [t-SNE] Iteration 900: error = 0.6838946, gradient norm = 0.0002075 (50 iterations in 0.024s)
# [t-SNE] Iteration 950: error = 0.6838577, gradient norm = 0.0002214 (50 iterations in 0.030s)
# [t-SNE] Iteration 1000: error = 0.6838136, gradient norm = 0.0001931 (50 iterations in 0.030s)
# [t-SNE] Iteration 1000: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 1000 iterations: 0.683814
# [t-SNE] Computed conditional probabilities for sample 177 / 177
# [t-SNE] Mean sigma: 0.412821
# Beginning preprocessing + Leiden
# Affmat shape: 177
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.1s
# Quality: 0.3203600027886822
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  30 out of  30 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 39, 1: 39, 2: 33, 3: 32, 4: 19, 5: 15})
# On pattern 1
# [t-SNE] Computing 29 nearest neighbors...
# [t-SNE] Indexed 30 samples in 0.001s...
# [t-SNE] Computed neighbors for 30 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 30 / 30
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.002s
# [t-SNE] Iteration 50: error = 43.2136383, gradient norm = 0.3478597 (50 iterations in 0.027s)
# [t-SNE] Iteration 100: error = 44.5518417, gradient norm = 0.6739807 (50 iterations in 0.025s)
# [t-SNE] Iteration 150: error = 43.4177361, gradient norm = 0.7131931 (50 iterations in 0.022s)
# [t-SNE] Iteration 200: error = 41.6086464, gradient norm = 0.7720285 (50 iterations in 0.009s)
# [t-SNE] Iteration 250: error = 44.0026779, gradient norm = 0.6494718 (50 iterations in 0.010s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 44.002678
# [t-SNE] Iteration 300: error = 0.5412545, gradient norm = 0.0008786 (50 iterations in 0.009s)
# [t-SNE] Iteration 350: error = 0.5014573, gradient norm = 0.0001532 (50 iterations in 0.023s)
# [t-SNE] Iteration 400: error = 0.4985776, gradient norm = 0.0001295 (50 iterations in 0.050s)
# [t-SNE] Iteration 450: error = 0.4968584, gradient norm = 0.0002906 (50 iterations in 0.020s)
# [t-SNE] Iteration 500: error = 0.4996189, gradient norm = 0.0000658 (50 iterations in 0.009s)
# [t-SNE] Iteration 550: error = 0.4992933, gradient norm = 0.0000348 (50 iterations in 0.012s)
# [t-SNE] Iteration 600: error = 0.4996445, gradient norm = 0.0000283 (50 iterations in 0.014s)
# [t-SNE] Iteration 650: error = 0.4995142, gradient norm = 0.0000359 (50 iterations in 0.013s)
# [t-SNE] Iteration 700: error = 0.4991307, gradient norm = 0.0000372 (50 iterations in 0.014s)
# [t-SNE] Iteration 750: error = 0.4987718, gradient norm = 0.0000994 (50 iterations in 0.037s)
# [t-SNE] Iteration 800: error = 0.4968458, gradient norm = 0.0001810 (50 iterations in 0.015s)
# [t-SNE] Iteration 850: error = 0.4904195, gradient norm = 0.0013149 (50 iterations in 0.009s)
# [t-SNE] Iteration 900: error = 0.7851077, gradient norm = 0.0012613 (50 iterations in 0.010s)
# [t-SNE] Iteration 950: error = 0.6122080, gradient norm = 0.0004419 (50 iterations in 0.011s)
# [t-SNE] Iteration 1000: error = 0.5401682, gradient norm = 0.0002595 (50 iterations in 0.012s)
# [t-SNE] KL divergence after 1000 iterations: 0.540168
# [t-SNE] Computed conditional probabilities for sample 30 / 30
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 30
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.9s
# Quality: 1.9095836023552904e-14
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  23 out of  23 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 30})
# On pattern 2
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 23 samples in 0.001s...
# [t-SNE] Computed neighbors for 23 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 23 / 23
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.001s
# [t-SNE] Iteration 50: error = 46.0002785, gradient norm = 0.4982804 (50 iterations in 0.014s)
# [t-SNE] Iteration 100: error = 44.1054688, gradient norm = 0.5513866 (50 iterations in 0.010s)
# [t-SNE] Iteration 150: error = 48.6219025, gradient norm = 0.4345824 (50 iterations in 0.011s)
# [t-SNE] Iteration 200: error = 44.8836632, gradient norm = 0.4291351 (50 iterations in 0.010s)
# [t-SNE] Iteration 250: error = 48.0164375, gradient norm = 0.5554816 (50 iterations in 0.009s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 48.016438
# [t-SNE] Iteration 300: error = 0.4577458, gradient norm = 0.0007066 (50 iterations in 0.009s)
# [t-SNE] Iteration 350: error = 0.4378477, gradient norm = 0.0000821 (50 iterations in 0.009s)
# [t-SNE] Iteration 400: error = 0.4372339, gradient norm = 0.0000406 (50 iterations in 0.013s)
# [t-SNE] Iteration 450: error = 0.4366888, gradient norm = 0.0000564 (50 iterations in 0.009s)
# [t-SNE] Iteration 500: error = 0.4332761, gradient norm = 0.0001057 (50 iterations in 0.009s)
# [t-SNE] Iteration 550: error = 0.4351356, gradient norm = 0.0000814 (50 iterations in 0.010s)
# [t-SNE] Iteration 600: error = 0.4351943, gradient norm = 0.0000679 (50 iterations in 0.009s)
# [t-SNE] Iteration 650: error = 0.4347445, gradient norm = 0.0000749 (50 iterations in 0.009s)
# [t-SNE] Iteration 700: error = 0.4343034, gradient norm = 0.0001105 (50 iterations in 0.009s)
# [t-SNE] Iteration 750: error = 0.4340145, gradient norm = 0.0000991 (50 iterations in 0.010s)
# [t-SNE] Iteration 800: error = 0.4349161, gradient norm = 0.0001046 (50 iterations in 0.009s)
# [t-SNE] Iteration 850: error = 0.4350750, gradient norm = 0.0001131 (50 iterations in 0.009s)
# [t-SNE] Iteration 850: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 850 iterations: 0.435075
# [t-SNE] Computed conditional probabilities for sample 23 / 23
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 23
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.9s
# Quality: 8.881784197001296e-16
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.5s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  14 out of  21 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  21 out of  21 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 23})
# On pattern 3
# [t-SNE] Computing 20 nearest neighbors...
# [t-SNE] Indexed 21 samples in 0.000s...
# [t-SNE] Computed neighbors for 21 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 21 / 21
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.002s
# [t-SNE] Iteration 50: error = 48.0560837, gradient norm = 0.3865097 (50 iterations in 0.009s)
# [t-SNE] Iteration 100: error = 47.6853371, gradient norm = 0.4990253 (50 iterations in 0.009s)
# [t-SNE] Iteration 150: error = 44.5329323, gradient norm = 0.6750193 (50 iterations in 0.009s)
# [t-SNE] Iteration 200: error = 44.3952332, gradient norm = 0.6440527 (50 iterations in 0.010s)
# [t-SNE] Iteration 250: error = 42.6491356, gradient norm = 0.4963783 (50 iterations in 0.009s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 42.649136
# [t-SNE] Iteration 300: error = 0.4813173, gradient norm = 0.0009006 (50 iterations in 0.009s)
# [t-SNE] Iteration 350: error = 0.4248125, gradient norm = 0.0001761 (50 iterations in 0.009s)
# [t-SNE] Iteration 400: error = 0.4192416, gradient norm = 0.0000966 (50 iterations in 0.009s)
# [t-SNE] Iteration 450: error = 0.4176630, gradient norm = 0.0000466 (50 iterations in 0.009s)
# [t-SNE] Iteration 500: error = 0.4166081, gradient norm = 0.0000649 (50 iterations in 0.009s)
# [t-SNE] Iteration 550: error = 0.4153454, gradient norm = 0.0000635 (50 iterations in 0.010s)
# [t-SNE] Iteration 600: error = 0.4148296, gradient norm = 0.0000460 (50 iterations in 0.009s)
# [t-SNE] Iteration 650: error = 0.4154309, gradient norm = 0.0000419 (50 iterations in 0.011s)
# [t-SNE] Iteration 700: error = 0.4146249, gradient norm = 0.0000667 (50 iterations in 0.009s)
# [t-SNE] Iteration 750: error = 0.4150544, gradient norm = 0.0000737 (50 iterations in 0.013s)
# [t-SNE] Iteration 800: error = 0.4147281, gradient norm = 0.0001840 (50 iterations in 0.009s)
# [t-SNE] Iteration 850: error = 0.4081383, gradient norm = 0.0268776 (50 iterations in 0.018s)
# [t-SNE] Iteration 900: error = 0.5230504, gradient norm = 0.0009425 (50 iterations in 0.040s)
# [t-SNE] Iteration 950: error = 0.4212008, gradient norm = 0.0001764 (50 iterations in 0.030s)
# [t-SNE] Iteration 1000: error = 0.4171422, gradient norm = 0.0000292 (50 iterations in 0.027s)
# [t-SNE] KL divergence after 1000 iterations: 0.417142
# [t-SNE] Computed conditional probabilities for sample 21 / 21
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 21
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.0s
# Quality: 4.44089209850064e-16
# Got subclusters: Counter({0: 21})
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.5s finished

# %%
import h5py
import modisco.util
reload(modisco.util)
![[ -e ../results/Cm/results.hdf5 ]] && rm ../results/Cm/results.hdf5
grp = h5py.File("../results/Cm/results.hdf5", "w")
tfmodisco_results.save_hdf5(grp)
grp.close()

# %%
from collections import Counter
from modisco.visualization import viz_sequence
reload(viz_sequence)
from matplotlib import pyplot as plt

import modisco.affinitymat.core
reload(modisco.affinitymat.core)
import modisco.cluster.phenograph.core
reload(modisco.cluster.phenograph.core)
import modisco.cluster.phenograph.cluster
reload(modisco.cluster.phenograph.cluster)
import modisco.cluster.core
reload(modisco.cluster.core)
import modisco.aggregator
reload(modisco.aggregator)

hdf5_results = h5py.File(data_dir + "results.hdf5","r")

print("Metaclusters heatmap")
import seaborn as sns
activity_patterns = np.array(hdf5_results['metaclustering_results']['attribute_vectors'])[
                    np.array(
        [x[0] for x in sorted(
                enumerate(hdf5_results['metaclustering_results']['metacluster_indices']),
               key=lambda x: x[1])])]
sns.heatmap(activity_patterns, center=0)
plt.show()

metacluster_names = [
    x.decode("utf-8") for x in 
    list(hdf5_results["metaclustering_results"]
         ["all_metacluster_names"][:])]

all_patterns = []
background = np.array([0.257, 0.227, 0.240, 0.276])

for metacluster_name in metacluster_names:
    print(metacluster_name)
    metacluster_grp = (hdf5_results["metacluster_idx_to_submetacluster_results"]
                                   [metacluster_name])
    print("activity pattern:",metacluster_grp["activity_pattern"][:])
    all_pattern_names = [x.decode("utf-8") for x in 
                         list(metacluster_grp["seqlets_to_patterns_result"]
                                             ["patterns"]["all_pattern_names"][:])]
    if (len(all_pattern_names)==0):
        print("No motifs found for this activity pattern")
    for pattern_name in all_pattern_names:
        print(metacluster_name, pattern_name)
        all_patterns.append((metacluster_name, pattern_name))
        pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
        print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
        
        print("onehot, fwd and rev:")
        viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["fwd"]),
                                                        background=background)) 
        
hdf5_results.close()
# Out:
# Metaclusters heatmap
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_0
# total seqlets: 177
# onehot, fwd and rev:
# metacluster_0 pattern_1
# total seqlets: 30
# onehot, fwd and rev:
# metacluster_0 pattern_2
# total seqlets: 23
# onehot, fwd and rev:
# metacluster_0 pattern_3
# total seqlets: 21
# onehot, fwd and rev:
