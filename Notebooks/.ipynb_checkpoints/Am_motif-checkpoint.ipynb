# %%
import numpy as np
import modisco
from importlib import reload
from collections import OrderedDict

import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = '../results/Am/'

task_to_scores = OrderedDict()
task_to_hyp_scores = OrderedDict()
task_to_scores['Am'] = np.load(data_dir + 'shuffle_task_to_scores.npy', allow_pickle=True)
task_to_hyp_scores['Am'] = np.load(data_dir + 'shuffle_task_to_hyp_scores.npy', allow_pickle=True)
onehot_data = np.load(data_dir + 'shuffle_onehot_data.npy', allow_pickle=True)

# %%
import modisco.visualization
from modisco.visualization import viz_sequence

viz_sequence.plot_weights(task_to_scores['Am'][1], subticks_frequency=5)
viz_sequence.plot_weights(task_to_hyp_scores['Am'][1], subticks_frequency=5)
viz_sequence.plot_weights(onehot_data[1], subticks_frequency=5)

# %%
null_per_pos_scores = modisco.coordproducers.LaplaceNullDist(num_to_samp=5000)
tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                    #Slight modifications from the default settings
                    sliding_window_size=7,
                    flank_size=3,
                    target_seqlet_fdr=0.01,
                    seqlets_to_patterns_factory=
                     modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                        trim_to_window_size=7,
                        initial_flank_to_add=3,
                        kmer_len=8, num_gaps=3,
                        num_mismatches=2,
                        final_min_cluster_size=20)
                )(
                 task_names=["Am"],
                 contrib_scores=task_to_scores,
                 hypothetical_contribs=task_to_hyp_scores,
                 one_hot=onehot_data,
                 null_per_pos_scores = null_per_pos_scores,
                 revcomp=False
)
# Out:
# TF-MoDISco is using the TensorFlow backend.
# WARNING:tensorflow:From /Users/daiyun/anaconda3/envs/disco/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# MEMORY 0.283353088
# On task Am
# Computing windowed sums on original
# Generating null dist
# peak(mu)= 0.014907861274201423
# Computing threshold
# For increasing = True , the minimum IR precision was 0.3791314889379573 occurring at 1.1369585990905762e-05 implying a frac_neg of 0.6106469923710965
# To be conservative, adjusted frac neg is 0.95
# For increasing = False , the minimum IR precision was 0.4376743188157048 occurring at -8.940696716308594e-07 implying a frac_neg of 0.7783288821060664
# To be conservative, adjusted frac neg is 0.95
# Thresholds from null dist were -0.2775372266769409  and  0.528704822063446 with frac passing 0.006328705198579271
# Passing windows frac was 0.006328705198579271 , which is below  0.03 ; adjusting
# Final raw thresholds are -0.3293094122409819  and  0.3293094122409819
# Final transformed thresholds are -0.9699709396189861  and  0.9699709396189861
# Got 126 coords
# After resolving overlaps, got 126 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.9698709396189861
# MEMORY 0.285208576
# 126 identified in total
# 1 activity patterns with support >= 100 out of 2 possible patterns
# Metacluster sizes:  [120]
# Idx to activities:  {0: '1'}
# MEMORY 0.285229056
# On metacluster 0
# Metacluster size 120
# Relevant tasks:  ('Am',)
# Relevant signs:  (1,)
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 120
# (Round 1) Computing coarse affmat
# MEMORY 0.323100672
# Beginning embedding computation
# MEMORY 0.323104768
# Computing embeddings
# MAKING A SESSION
# 2022-05-22 16:57:36.689096: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# Finished embedding computation in 0.52 s
# MEMORY 0.45635584
# Starting affinity matrix computations
# MEMORY 0.45635584
# Batching in slices of size 120
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 45.22it/s]
# Finished affinity matrix computations in 0.05 s
# MEMORY 0.449196032
# (Round 1) Computed coarse affmat
# MEMORY 0.448933888
# (Round 1) Computing affinity matrix on nearest neighbors
# MEMORY 0.448933888
# Launching nearest neighbors affmat calculation job
# MEMORY 0.44894208
# Parallel runs completed
# MEMORY 0.349151232
# Job completed in: 0.28 s
# MEMORY 0.349151232
# (Round 1) Computed affinity matrix on nearest neighbors in 0.37 s
# MEMORY 0.348995584
# Filtered down to 120 of 120
# (Round 1) Retained 120 rows out of 120 after filtering
# MEMORY 0.349065216
# (Round 1) Computing density adapted affmat
# MEMORY 0.349069312
# Symmetrizing nearest neighbors
# Computing betas for density adaptation
# Computing normalizing denominators
# (Round 1) Computing clustering
# MEMORY 0.354398208
# Beginning preprocessing + Leiden
# Affmat shape: 120
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.9s
# Quality: 0.03227071258229998
# Got 4 clusters after round 1
# Counts:
# {2: 24, 3: 23, 0: 38, 1: 35}
# MEMORY 0.353615872
# (Round 1) Aggregating seqlets in each cluster
# MEMORY 0.353615872
# Aggregating for cluster 0 with 38 seqlets
# MEMORY 0.353615872
# Trimming eliminated 0 seqlets out of 38
# Aggregating for cluster 1 with 35 seqlets
# MEMORY 0.353624064
# Trimming eliminated 0 seqlets out of 35
# Aggregating for cluster 2 with 24 seqlets
# MEMORY 0.353624064
# Skipped 1 seqlets that went over sequence edge during flank expansion
# Trimming eliminated 0 seqlets out of 23
# Aggregating for cluster 3 with 23 seqlets
# MEMORY 0.353624064
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.3s finished
# Trimming eliminated 0 seqlets out of 23
# (Round 2) num seqlets: 118
# (Round 2) Computing coarse affmat
# MEMORY 0.353030144
# Beginning embedding computation
# MEMORY 0.353030144
# Computing embeddings
# Finished embedding computation in 0.22 s
# MEMORY 0.448987136
# Starting affinity matrix computations
# MEMORY 0.448987136
# Batching in slices of size 118
# 100%|█████████████████████████████████████████████| 1/1 [00:00<00:00, 41.87it/s]
# Finished affinity matrix computations in 0.06 s
# MEMORY 0.449286144
# (Round 2) Computed coarse affmat
# MEMORY 0.44916736
# (Round 2) Computing affinity matrix on nearest neighbors
# MEMORY 0.44916736
# Launching nearest neighbors affmat calculation job
# MEMORY 0.44916736
# Parallel runs completed
# MEMORY 0.352452608
# Job completed in: 0.29 s
# MEMORY 0.352452608
# (Round 2) Computed affinity matrix on nearest neighbors in 0.37 s
# MEMORY 0.352370688
# Not applying filtering for rounds above first round
# MEMORY 0.352370688
# (Round 2) Computing density adapted affmat
# MEMORY 0.352370688
# Symmetrizing nearest neighbors
# Computing betas for density adaptation
# Computing normalizing denominators
# (Round 2) Computing clustering
# MEMORY 0.357326848
# Beginning preprocessing + Leiden
# Affmat shape: 118
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.8s
# Quality: 0.02906174128680146
# Quality: 0.029238352701656745
# Quality: 0.02945335445891105
# Got 4 clusters after round 2
# Counts:
# {0: 45, 2: 25, 1: 28, 3: 20}
# MEMORY 0.355745792
# (Round 2) Aggregating seqlets in each cluster
# MEMORY 0.355745792
# Aggregating for cluster 0 with 45 seqlets
# MEMORY 0.355745792
# Trimming eliminated 0 seqlets out of 45
# Aggregating for cluster 1 with 28 seqlets
# MEMORY 0.355745792
# Skipped 1 due to duplicates
# Trimming eliminated 0 seqlets out of 27
# Aggregating for cluster 2 with 25 seqlets
# MEMORY 0.355745792
# Trimming eliminated 0 seqlets out of 25
# Aggregating for cluster 3 with 20 seqlets
# MEMORY 0.355745792
# Trimming eliminated 0 seqlets out of 20
# Got 4 clusters
# Splitting into subclusters...
# MEMORY 0.355749888
# Inspecting pattern 0 for spurious merging
# Inspecting pattern 1 for spurious merging
# Inspecting pattern 2 for spurious merging
# Inspecting pattern 3 for spurious merging
# Merging on 4 clusters
# MEMORY 0.355749888
# On merging iteration 1
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.3s finished
# Numbers for each pattern pre-subsample: [45, 27, 25, 20]
# Numbers after subsampling: [45, 27, 25, 20]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.16370487213134766 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.11227011680603027 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.10870003700256348 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.08492898941040039 s
# Cluster sizes
# [45 27 25 20]
# Cross-contamination matrix:
# [[1.   0.3  0.45 0.17]
#  [0.62 1.   0.49 0.4 ]
#  [0.69 0.34 1.   0.27]
#  [0.55 0.5  0.53 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.61 0.76 0.62]
#  [0.61 1.   0.57 0.54]
#  [0.76 0.57 1.   0.55]
#  [0.62 0.54 0.55 1.  ]]
# Got 4 patterns after merging
# MEMORY 0.355815424
# Performing filtering
# MEMORY 0.355815424
# Got 4 patterns after filtering
# MEMORY 0.355815424
# Total time taken is 10.87s
# MEMORY 0.355815424
# Applying subclustering to the final motifs
# On pattern 0
# [t-SNE] Computing 44 nearest neighbors...
# [t-SNE] Indexed 45 samples in 0.001s...
# [t-SNE] Computed neighbors for 45 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 45 / 45
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.002s
# [t-SNE] Iteration 50: error = 49.4132080, gradient norm = 0.3649440 (50 iterations in 0.010s)
# [t-SNE] Iteration 100: error = 43.2783279, gradient norm = 0.4182964 (50 iterations in 0.011s)
# [t-SNE] Iteration 150: error = 48.2020035, gradient norm = 0.6657472 (50 iterations in 0.010s)
# [t-SNE] Iteration 200: error = 42.3871765, gradient norm = 0.5487152 (50 iterations in 0.012s)
# [t-SNE] Iteration 250: error = 45.2206688, gradient norm = 0.5526590 (50 iterations in 0.012s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 45.220669
# [t-SNE] Iteration 300: error = 0.7855161, gradient norm = 0.0010573 (50 iterations in 0.011s)
# [t-SNE] Iteration 350: error = 0.6862543, gradient norm = 0.0004566 (50 iterations in 0.013s)
# [t-SNE] Iteration 400: error = 0.6319196, gradient norm = 0.0002736 (50 iterations in 0.014s)
# [t-SNE] Iteration 450: error = 0.5932616, gradient norm = 0.0000688 (50 iterations in 0.010s)
# [t-SNE] Iteration 500: error = 0.5919732, gradient norm = 0.0000236 (50 iterations in 0.012s)
# [t-SNE] Iteration 550: error = 0.5917646, gradient norm = 0.0000142 (50 iterations in 0.016s)
# [t-SNE] Iteration 600: error = 0.5915008, gradient norm = 0.0000137 (50 iterations in 0.017s)
# [t-SNE] Iteration 650: error = 0.5912544, gradient norm = 0.0000144 (50 iterations in 0.012s)
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  45 out of  45 | elapsed:    0.0s finished
# [t-SNE] Iteration 700: error = 0.5912801, gradient norm = 0.0000124 (50 iterations in 0.022s)
# [t-SNE] Iteration 750: error = 0.5914063, gradient norm = 0.0000125 (50 iterations in 0.012s)
# [t-SNE] Iteration 800: error = 0.5913713, gradient norm = 0.0000122 (50 iterations in 0.010s)
# [t-SNE] Iteration 850: error = 0.5916407, gradient norm = 0.0000117 (50 iterations in 0.010s)
# [t-SNE] Iteration 900: error = 0.5916089, gradient norm = 0.0000115 (50 iterations in 0.023s)
# [t-SNE] Iteration 950: error = 0.5911118, gradient norm = 0.0000353 (50 iterations in 0.011s)
# [t-SNE] Iteration 1000: error = 0.5912350, gradient norm = 0.0000147 (50 iterations in 0.011s)
# [t-SNE] KL divergence after 1000 iterations: 0.591235
# [t-SNE] Computed conditional probabilities for sample 45 / 45
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 45
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.9s
# Quality: -1.6509016376176883e-13
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.4s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  20 out of  27 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  27 out of  27 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 45})
# On pattern 1
# [t-SNE] Computing 26 nearest neighbors...
# [t-SNE] Indexed 27 samples in 0.001s...
# [t-SNE] Computed neighbors for 27 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 27 / 27
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.002s
# [t-SNE] Iteration 50: error = 46.7478409, gradient norm = 0.4568534 (50 iterations in 0.013s)
# [t-SNE] Iteration 100: error = 47.4522324, gradient norm = 0.4579464 (50 iterations in 0.016s)
# [t-SNE] Iteration 150: error = 44.4867172, gradient norm = 0.5431890 (50 iterations in 0.015s)
# [t-SNE] Iteration 200: error = 47.4877167, gradient norm = 0.2723247 (50 iterations in 0.017s)
# [t-SNE] Iteration 250: error = 42.5813217, gradient norm = 0.4632013 (50 iterations in 0.014s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 42.581322
# [t-SNE] Iteration 300: error = 0.5378405, gradient norm = 0.0008411 (50 iterations in 0.016s)
# [t-SNE] Iteration 350: error = 0.4848757, gradient norm = 0.0001641 (50 iterations in 0.010s)
# [t-SNE] Iteration 400: error = 0.4762222, gradient norm = 0.0000924 (50 iterations in 0.024s)
# [t-SNE] Iteration 450: error = 0.4743284, gradient norm = 0.0000370 (50 iterations in 0.016s)
# [t-SNE] Iteration 500: error = 0.4741376, gradient norm = 0.0000293 (50 iterations in 0.013s)
# [t-SNE] Iteration 550: error = 0.4739683, gradient norm = 0.0000498 (50 iterations in 0.009s)
# [t-SNE] Iteration 600: error = 0.4733741, gradient norm = 0.0000423 (50 iterations in 0.026s)
# [t-SNE] Iteration 650: error = 0.4732074, gradient norm = 0.0000420 (50 iterations in 0.016s)
# [t-SNE] Iteration 700: error = 0.4729972, gradient norm = 0.0000451 (50 iterations in 0.012s)
# [t-SNE] Iteration 750: error = 0.4729452, gradient norm = 0.0000625 (50 iterations in 0.013s)
# [t-SNE] Iteration 800: error = 0.4720533, gradient norm = 0.0001371 (50 iterations in 0.016s)
# [t-SNE] Iteration 850: error = 0.4644252, gradient norm = 0.0012034 (50 iterations in 0.016s)
# [t-SNE] Iteration 900: error = 0.5938156, gradient norm = 0.0012834 (50 iterations in 0.017s)
# [t-SNE] Iteration 950: error = 0.4969389, gradient norm = 0.0003031 (50 iterations in 0.019s)
# [t-SNE] Iteration 1000: error = 0.4864767, gradient norm = 0.0001352 (50 iterations in 0.025s)
# [t-SNE] KL divergence after 1000 iterations: 0.486477
# [t-SNE] Computed conditional probabilities for sample 27 / 27
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 27
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.8s
# Quality: 6.306066779870841e-14
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  18 out of  25 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 27})
# On pattern 2
# [t-SNE] Computing 24 nearest neighbors...
# [t-SNE] Indexed 25 samples in 0.001s...
# [t-SNE] Computed neighbors for 25 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 25 / 25
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.001s
# [t-SNE] Iteration 50: error = 48.3642426, gradient norm = 0.4966776 (50 iterations in 0.013s)
# [t-SNE] Iteration 100: error = 51.4994125, gradient norm = 0.5245329 (50 iterations in 0.013s)
# [t-SNE] Iteration 150: error = 41.6517563, gradient norm = 0.7918428 (50 iterations in 0.012s)
# [t-SNE] Iteration 200: error = 47.2219238, gradient norm = 0.3785344 (50 iterations in 0.012s)
# [t-SNE] Iteration 250: error = 41.7042084, gradient norm = 0.6758102 (50 iterations in 0.014s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 41.704208
# [t-SNE] Iteration 300: error = 0.7896508, gradient norm = 0.0010434 (50 iterations in 0.013s)
# [t-SNE] Iteration 350: error = 0.5834734, gradient norm = 0.0004763 (50 iterations in 0.012s)
# [t-SNE] Iteration 400: error = 0.4956892, gradient norm = 0.0002529 (50 iterations in 0.011s)
# [t-SNE] Iteration 450: error = 0.4684072, gradient norm = 0.0000595 (50 iterations in 0.010s)
# [t-SNE] Iteration 500: error = 0.4657343, gradient norm = 0.0000538 (50 iterations in 0.011s)
# [t-SNE] Iteration 550: error = 0.4612250, gradient norm = 0.0000620 (50 iterations in 0.015s)
# [t-SNE] Iteration 600: error = 0.4561540, gradient norm = 0.0000387 (50 iterations in 0.014s)
# [t-SNE] Iteration 650: error = 0.4550202, gradient norm = 0.0000190 (50 iterations in 0.011s)
# [t-SNE] Iteration 700: error = 0.4546073, gradient norm = 0.0000139 (50 iterations in 0.010s)
# [t-SNE] Iteration 750: error = 0.4544798, gradient norm = 0.0000113 (50 iterations in 0.016s)
# [t-SNE] Iteration 800: error = 0.4541106, gradient norm = 0.0000161 (50 iterations in 0.015s)
# [t-SNE] Iteration 850: error = 0.4539843, gradient norm = 0.0000143 (50 iterations in 0.010s)
# [t-SNE] Iteration 900: error = 0.4538447, gradient norm = 0.0000183 (50 iterations in 0.010s)
# [t-SNE] Iteration 950: error = 0.4536364, gradient norm = 0.0000168 (50 iterations in 0.012s)
# [t-SNE] Iteration 1000: error = 0.4529509, gradient norm = 0.0000182 (50 iterations in 0.010s)
# [t-SNE] KL divergence after 1000 iterations: 0.452951
# [t-SNE] Computed conditional probabilities for sample 25 / 25
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 25
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.8s
# Quality: -1.332267629550175e-14
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  20 out of  20 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 25})
# On pattern 3
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 20 samples in 0.001s...
# [t-SNE] Computed neighbors for 20 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 1125899906842624.000000
# [t-SNE] Computed conditional probabilities in 0.001s
# [t-SNE] Iteration 50: error = 49.2328720, gradient norm = 0.5608081 (50 iterations in 0.012s)
# [t-SNE] Iteration 100: error = 46.4881554, gradient norm = 0.4801966 (50 iterations in 0.011s)
# [t-SNE] Iteration 150: error = 43.9348679, gradient norm = 0.5333685 (50 iterations in 0.010s)
# [t-SNE] Iteration 200: error = 46.6968002, gradient norm = 0.3998051 (50 iterations in 0.010s)
# [t-SNE] Iteration 250: error = 49.8732796, gradient norm = 0.7177394 (50 iterations in 0.013s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.873280
# [t-SNE] Iteration 300: error = 0.7730783, gradient norm = 0.0013238 (50 iterations in 0.010s)
# [t-SNE] Iteration 350: error = 0.5181678, gradient norm = 0.0003587 (50 iterations in 0.010s)
# [t-SNE] Iteration 400: error = 0.4530118, gradient norm = 0.0002605 (50 iterations in 0.009s)
# [t-SNE] Iteration 450: error = 0.4186904, gradient norm = 0.0001123 (50 iterations in 0.014s)
# [t-SNE] Iteration 500: error = 0.4097727, gradient norm = 0.0000629 (50 iterations in 0.011s)
# [t-SNE] Iteration 550: error = 0.4081854, gradient norm = 0.0000323 (50 iterations in 0.009s)
# [t-SNE] Iteration 600: error = 0.4077696, gradient norm = 0.0000200 (50 iterations in 0.009s)
# [t-SNE] Iteration 650: error = 0.4074994, gradient norm = 0.0000174 (50 iterations in 0.032s)
# [t-SNE] Iteration 700: error = 0.4073770, gradient norm = 0.0000161 (50 iterations in 0.032s)
# [t-SNE] Iteration 750: error = 0.4039864, gradient norm = 0.0000229 (50 iterations in 0.028s)
# [t-SNE] Iteration 800: error = 0.4037811, gradient norm = 0.0000198 (50 iterations in 0.013s)
# [t-SNE] Iteration 850: error = 0.4064884, gradient norm = 0.0000143 (50 iterations in 0.010s)
# [t-SNE] Iteration 900: error = 0.4063544, gradient norm = 0.0000145 (50 iterations in 0.009s)
# [t-SNE] Iteration 950: error = 0.4063016, gradient norm = 0.0000140 (50 iterations in 0.011s)
# [t-SNE] Iteration 1000: error = 0.4061719, gradient norm = 0.0000276 (50 iterations in 0.009s)
# [t-SNE] KL divergence after 1000 iterations: 0.406172
# [t-SNE] Computed conditional probabilities for sample 20 / 20
# [t-SNE] Mean sigma: 1125899906842624.000000
# Beginning preprocessing + Leiden
# Affmat shape: 20
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.0s
# Quality: 4.1522341120980754e-14
# Got subclusters: Counter({0: 20})
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.5s finished

# %%
import h5py
import modisco.util
reload(modisco.util)
![[ -e ../results/Am/results.hdf5 ]] && rm ../results/Am/results.hdf5
grp = h5py.File(data_dir + "results.hdf5", "w")
tfmodisco_results.save_hdf5(grp)
grp.close()

# %%
from collections import Counter
from modisco.visualization import viz_sequence
reload(viz_sequence)
from matplotlib import pyplot as plt

import modisco.affinitymat.core
reload(modisco.affinitymat.core)
import modisco.cluster.phenograph.core
reload(modisco.cluster.phenograph.core)
import modisco.cluster.phenograph.cluster
reload(modisco.cluster.phenograph.cluster)
import modisco.cluster.core
reload(modisco.cluster.core)
import modisco.aggregator
reload(modisco.aggregator)

hdf5_results = h5py.File(data_dir + "results.hdf5","r")

print("Metaclusters heatmap")
import seaborn as sns
activity_patterns = np.array(hdf5_results['metaclustering_results']['attribute_vectors'])[
                    np.array(
        [x[0] for x in sorted(
                enumerate(hdf5_results['metaclustering_results']['metacluster_indices']),
               key=lambda x: x[1])])]
sns.heatmap(activity_patterns, center=0)
plt.show()

metacluster_names = [
    x.decode("utf-8") for x in 
    list(hdf5_results["metaclustering_results"]
         ["all_metacluster_names"][:])]

all_patterns = []
background = np.array([0.284, 0.201, 0.213, 0.302])

for metacluster_name in metacluster_names:
    print(metacluster_name)
    metacluster_grp = (hdf5_results["metacluster_idx_to_submetacluster_results"]
                                   [metacluster_name])
    print("activity pattern:",metacluster_grp["activity_pattern"][:])
    all_pattern_names = [x.decode("utf-8") for x in 
                         list(metacluster_grp["seqlets_to_patterns_result"]
                                             ["patterns"]["all_pattern_names"][:])]
    if (len(all_pattern_names)==0):
        print("No motifs found for this activity pattern")
    for pattern_name in all_pattern_names:
        print(metacluster_name, pattern_name)
        all_patterns.append((metacluster_name, pattern_name))
        pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
        print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
        
        print("onehot, fwd and rev:")
        viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["fwd"]),
                                                        background=background)) 
        
hdf5_results.close()
# Out:
# Metaclusters heatmap
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_0
# total seqlets: 45
# onehot, fwd and rev:
# metacluster_0 pattern_1
# total seqlets: 27
# onehot, fwd and rev:
# metacluster_0 pattern_2
# total seqlets: 25
# onehot, fwd and rev:
# metacluster_0 pattern_3
# total seqlets: 20
# onehot, fwd and rev:
