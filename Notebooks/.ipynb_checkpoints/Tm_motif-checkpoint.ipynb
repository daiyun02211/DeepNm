# %%
import numpy as np
import modisco
from importlib import reload
from collections import OrderedDict

import warnings
warnings.filterwarnings('ignore')

# %%
data_dir = '../results/Tm/'

task_to_scores = OrderedDict()
task_to_hyp_scores = OrderedDict()
task_to_scores['Tm'] = np.load(data_dir + 'shuffle_task_to_scores.npy', allow_pickle=True)
task_to_hyp_scores['Tm'] = np.load(data_dir + 'shuffle_task_to_hyp_scores.npy', allow_pickle=True)
onehot_data = np.load(data_dir + 'shuffle_onehot_data.npy', allow_pickle=True)

# %%
import modisco.visualization
from modisco.visualization import viz_sequence

viz_sequence.plot_weights(task_to_scores['Tm'][1], subticks_frequency=5)
viz_sequence.plot_weights(task_to_hyp_scores['Tm'][1], subticks_frequency=5)
viz_sequence.plot_weights(onehot_data[1], subticks_frequency=5)

# %%
null_per_pos_scores = modisco.coordproducers.LaplaceNullDist(num_to_samp=5000)
tfmodisco_results = modisco.tfmodisco_workflow.workflow.TfModiscoWorkflow(
                    #Slight modifications from the default settings
                    sliding_window_size=7,
                    flank_size=3,
                    target_seqlet_fdr=0.01,
                    seqlets_to_patterns_factory=
                     modisco.tfmodisco_workflow.seqlets_to_patterns.TfModiscoSeqletsToPatternsFactory(
                        trim_to_window_size=7,
                        initial_flank_to_add=3,
                        kmer_len=8, num_gaps=3,
                        num_mismatches=2,
                        final_min_cluster_size=50)
                )(
                 task_names=["Tm"],
                 contrib_scores=task_to_scores,
                 hypothetical_contribs=task_to_hyp_scores,
                 one_hot=onehot_data,
                 null_per_pos_scores = null_per_pos_scores,
                 revcomp=False
)
# Out:
# TF-MoDISco is using the TensorFlow backend.
# WARNING:tensorflow:From /Users/daiyun/anaconda3/envs/disco/lib/python3.7/site-packages/tensorflow/python/compat/v2_compat.py:61: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# MEMORY 0.288391168
# On task Tm
# Computing windowed sums on original
# Generating null dist
# peak(mu)= 2.605948597192766e-06
# Computing threshold
# For increasing = True , the minimum IR precision was 0.4303435322729808 occurring at 1.3113021850585938e-06 implying a frac_neg of 0.755443950263727
# To be conservative, adjusted frac neg is 0.95
# For increasing = False , the minimum IR precision was 0.23976247170532378 occurring at -2.384185791015625e-07 implying a frac_neg of 0.31537836897258414
# To be conservative, adjusted frac neg is 0.95
# Thresholds from null dist were -0.2653477415442467  and  0.4732857793569565 with frac passing 0.027183426977028628
# Passing windows frac was 0.027183426977028628 , which is below  0.03 ; adjusting
# Final raw thresholds are -0.4419819638133049  and  0.4419819638133049
# Final transformed thresholds are -0.9699957955891908  and  0.9699957955891908
# Got 931 coords
# After resolving overlaps, got 931 seqlets
# Across all tasks, the weakest transformed threshold used was: 0.9698957955891908
# MEMORY 0.309194752
# 931 identified in total
# 1 activity patterns with support >= 100 out of 2 possible patterns
# Metacluster sizes:  [916]
# Idx to activities:  {0: '1'}
# MEMORY 0.309215232
# On metacluster 0
# Metacluster size 916
# Relevant tasks:  ('Tm',)
# Relevant signs:  (1,)
# TfModiscoSeqletsToPatternsFactory: seed=1234
# (Round 1) num seqlets: 916
# (Round 1) Computing coarse affmat
# MEMORY 0.34238464
# Beginning embedding computation
# MEMORY 0.34238464
# Computing embeddings
# MAKING A SESSION
# 2022-05-23 08:33:49.060113: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# Finished embedding computation in 1.48 s
# MEMORY 0.662683648
# Starting affinity matrix computations
# MEMORY 0.662683648
# Batching in slices of size 916
# 100%|███████████████████████████████████████████████| 1/1 [00:00<00:00,  3.40it/s]
# Finished affinity matrix computations in 0.53 s
# MEMORY 0.64180224
# (Round 1) Computed coarse affmat
# MEMORY 0.431693824
# (Round 1) Computing affinity matrix on nearest neighbors
# MEMORY 0.431693824
# Launching nearest neighbors affmat calculation job
# MEMORY 0.433033216
# Parallel runs completed
# MEMORY 0.379584512
# Job completed in: 1.2 s
# MEMORY 0.379584512
# (Round 1) Computed affinity matrix on nearest neighbors in 1.4 s
# MEMORY 0.388415488
# Filtered down to 912 of 916
# (Round 1) Retained 912 rows out of 916 after filtering
# MEMORY 0.38848512
# (Round 1) Computing density adapted affmat
# MEMORY 0.416059392
# Symmetrizing nearest neighbors
# Computing betas for density adaptation
# Computing normalizing denominators
# (Round 1) Computing clustering
# MEMORY 0.5013504
# Beginning preprocessing + Leiden
# Affmat shape: 912
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   13.4s
# Quality: 0.13621736700807174
# Quality: 0.13623323197793685
# Got 3 clusters after round 1
# Counts:
# {2: 223, 1: 330, 0: 359}
# MEMORY 0.499654656
# (Round 1) Aggregating seqlets in each cluster
# MEMORY 0.499654656
# Aggregating for cluster 0 with 359 seqlets
# MEMORY 0.499654656
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:   16.1s finished
# Trimming eliminated 0 seqlets out of 359
# Aggregating for cluster 1 with 330 seqlets
# MEMORY 0.5001216
# Skipped 1 due to duplicates
# Trimming eliminated 0 seqlets out of 329
# Aggregating for cluster 2 with 223 seqlets
# MEMORY 0.500514816
# Trimming eliminated 0 seqlets out of 223
# (Round 2) num seqlets: 911
# (Round 2) Computing coarse affmat
# MEMORY 0.500555776
# Beginning embedding computation
# MEMORY 0.500555776
# Computing embeddings
# Finished embedding computation in 1.18 s
# MEMORY 0.760205312
# Starting affinity matrix computations
# MEMORY 0.760205312
# Batching in slices of size 911
# 100%|███████████████████████████████████████████████| 1/1 [00:00<00:00,  3.42it/s]
# Finished affinity matrix computations in 0.52 s
# MEMORY 0.733159424
# (Round 2) Computed coarse affmat
# MEMORY 0.524197888
# (Round 2) Computing affinity matrix on nearest neighbors
# MEMORY 0.524197888
# Launching nearest neighbors affmat calculation job
# MEMORY 0.525119488
# Parallel runs completed
# MEMORY 0.470626304
# Job completed in: 1.32 s
# MEMORY 0.470626304
# (Round 2) Computed affinity matrix on nearest neighbors in 1.52 s
# MEMORY 0.475062272
# Not applying filtering for rounds above first round
# MEMORY 0.475062272
# (Round 2) Computing density adapted affmat
# MEMORY 0.495398912
# Symmetrizing nearest neighbors
# Computing betas for density adaptation
# Computing normalizing denominators
# (Round 2) Computing clustering
# MEMORY 0.550920192
# Beginning preprocessing + Leiden
# Affmat shape: 911
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:   10.8s
# Quality: 0.17291039409397316
# Quality: 0.173016459093843
# Quality: 0.1730166279060637
# Got 3 clusters after round 2
# Counts:
# {0: 414, 2: 124, 1: 373}
# MEMORY 0.546213888
# (Round 2) Aggregating seqlets in each cluster
# MEMORY 0.546213888
# Aggregating for cluster 0 with 414 seqlets
# MEMORY 0.546213888
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:   12.7s finished
# Trimming eliminated 0 seqlets out of 414
# Aggregating for cluster 1 with 373 seqlets
# MEMORY 0.546213888
# Trimming eliminated 0 seqlets out of 373
# Aggregating for cluster 2 with 124 seqlets
# MEMORY 0.545992704
# Trimming eliminated 0 seqlets out of 124
# Got 3 clusters
# Splitting into subclusters...
# MEMORY 0.54577152
# Inspecting pattern 0 for spurious merging
# [t-SNE] Computed conditional probabilities for sample 414 / 414
# [t-SNE] Mean sigma: 0.352796
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 281 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 414 out of 414 | elapsed:    0.1s finished
# Beginning preprocessing + Leiden
# Affmat shape: 414
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.6s
# Quality: 0.4600743077054921
# Quality: 0.46252984543383036
# Quality: 0.4625666487049741
# Quality: 0.4628087790973198
# Quality: 0.46290820546523986
# Got subclusters: Counter({0: 110, 1: 86, 2: 81, 3: 48, 4: 45, 5: 44})
# On merging iteration 1
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    5.4s finished
# Numbers for each pattern pre-subsample: [110, 86, 81, 48, 45, 44]
# Numbers after subsampling: [110, 86, 81, 48, 45, 44]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.5191309452056885 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.49780988693237305 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.4609839916229248 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.2756481170654297 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.25770092010498047 s
# Computing sims for pattern 5
# Computed sims for pattern 5 in 0.253525972366333 s
# Cluster sizes
# [110  86  81  48  45  44]
# Cross-contamination matrix:
# [[1.   0.11 0.34 0.28 0.27 0.44]
#  [0.16 1.   0.71 0.5  0.67 0.7 ]
#  [0.26 0.56 1.   0.39 0.51 0.61]
#  [0.51 0.69 0.71 1.   0.62 0.72]
#  [0.38 0.76 0.75 0.51 1.   0.73]
#  [0.45 0.65 0.71 0.5  0.59 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.49 0.56 0.49 0.47 0.52]
#  [0.49 1.   0.88 0.83 0.87 0.88]
#  [0.56 0.88 1.   0.84 0.87 0.89]
#  [0.49 0.83 0.84 1.   0.78 0.8 ]
#  [0.47 0.87 0.87 0.78 1.   0.86]
#  [0.52 0.88 0.89 0.8  0.86 1.  ]]
# Collapsing 2 & 5 with crosscontam 0.6070931332324412 and sim 0.8935299398818931
# Collapsing 1 & 2 with crosscontam 0.5640330329608882 and sim 0.8815490635980481
# Collapsing 1 & 5 with crosscontam 0.65227283647546 and sim 0.8809256974556642
# Collapsing 1 & 4 with crosscontam 0.6716938969734321 and sim 0.8717156086727635
# Collapsing 2 & 4 with crosscontam 0.5135635209009297 and sim 0.8695380890673129
# Collapsing 4 & 5 with crosscontam 0.5916270139410635 and sim 0.8580170808259876
# Trimming eliminated 0 seqlets out of 125
# Trimming eliminated 0 seqlets out of 211
# Trimming eliminated 0 seqlets out of 256
# Unmerged patterns remapping: OrderedDict([(0, 1), (3, 2)])
# Time spent on merging iteration: 0.5761168003082275
# On merging iteration 2
# Numbers for each pattern pre-subsample: [256, 110, 48]
# Numbers after subsampling: [256, 110, 48]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.34940385818481445 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.1334362030029297 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.07330799102783203 s
# Cluster sizes
# [256 110  48]
# Cross-contamination matrix:
# [[1.   0.53 0.68]
#  [0.31 1.   0.28]
#  [0.68 0.51 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.48 0.86]
#  [0.48 1.   0.49]
#  [0.86 0.49 1.  ]]
# Collapsing 0 & 2 with crosscontam 0.6816090544064839 and sim 0.8561398481935489
# Trimming eliminated 0 seqlets out of 304
# Unmerged patterns remapping: OrderedDict([(1, 1)])
# Time spent on merging iteration: 0.35143518447875977
# On merging iteration 3
# Numbers for each pattern pre-subsample: [304, 110]
# Numbers after subsampling: [300, 110]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.2688446044921875 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.13602590560913086 s
# Cluster sizes
# [304 110]
# Cross-contamination matrix:
# [[1.   0.62]
#  [0.3  1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.49]
#  [0.49 1.  ]]
# Inspecting pattern 1 for spurious merging
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 241 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 373 out of 373 | elapsed:    0.1s finished
# [t-SNE] Computed conditional probabilities for sample 373 / 373
# [t-SNE] Mean sigma: 0.387292
# Beginning preprocessing + Leiden
# Affmat shape: 373
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    4.4s
# Quality: 0.45546931482980046
# Got subclusters: Counter({0: 90, 1: 79, 2: 72, 3: 67, 4: 65})
# On merging iteration 1
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    5.1s finished
# Numbers for each pattern pre-subsample: [90, 79, 72, 67, 65]
# Numbers after subsampling: [90, 79, 72, 67, 65]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.28189897537231445 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.35385608673095703 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.3191869258880615 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.2825310230255127 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.2669250965118408 s
# Cluster sizes
# [90 79 72 67 65]
# Cross-contamination matrix:
# [[1.   0.73 0.17 0.64 0.48]
#  [0.66 1.   0.2  0.6  0.43]
#  [0.27 0.37 1.   0.55 0.48]
#  [0.62 0.65 0.41 1.   0.46]
#  [0.6  0.61 0.5  0.58 1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.85 0.52 0.81 0.79]
#  [0.85 1.   0.62 0.85 0.83]
#  [0.52 0.62 1.   0.76 0.45]
#  [0.81 0.85 0.76 1.   0.7 ]
#  [0.79 0.83 0.45 0.7  1.  ]]
# Collapsing 0 & 1 with crosscontam 0.6601014884781484 and sim 0.8533235504904377
# Collapsing 1 & 3 with crosscontam 0.6042318168466767 and sim 0.8510350872984874
# Trimming eliminated 0 seqlets out of 169
# Trimming eliminated 0 seqlets out of 236
# Unmerged patterns remapping: OrderedDict([(2, 1), (4, 2)])
# Time spent on merging iteration: 0.515794038772583
# On merging iteration 2
# Numbers for each pattern pre-subsample: [236, 72, 65]
# Numbers after subsampling: [236, 72, 65]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.4296422004699707 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.09748697280883789 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.08573579788208008 s
# Cluster sizes
# [236  72  65]
# Cross-contamination matrix:
# [[1.   0.42 0.68]
#  [0.38 1.   0.48]
#  [0.6  0.5  1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.66 0.82]
#  [0.66 1.   0.45]
#  [0.82 0.45 1.  ]]
# Inspecting pattern 2 for spurious merging
# [t-SNE] Computed conditional probabilities for sample 124 / 124
# [t-SNE] Mean sigma: 0.466682
# Beginning preprocessing + Leiden
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 124 out of 124 | elapsed:    0.0s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# Affmat shape: 124
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.0s
# Quality: 0.24245247436271597
# Quality: 0.24253630512291224
# Quality: 0.24316748444468123
# Got subclusters: Counter({0: 34, 1: 32, 2: 27, 3: 14, 4: 8, 5: 6, 6: 3})
# On merging iteration 1
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.5s finished
# Numbers for each pattern pre-subsample: [34, 32, 27, 14, 8, 6, 3]
# Numbers after subsampling: [34, 32, 27, 14, 8, 6, 3]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.2654109001159668 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.2463521957397461 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 0.19942879676818848 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.14073705673217773 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.0857541561126709 s
# Computing sims for pattern 5
# Computed sims for pattern 5 in 0.06881499290466309 s
# Computing sims for pattern 6
# Computed sims for pattern 6 in 0.0510251522064209 s
# Cluster sizes
# [34 32 27 14  8  6  3]
# Cross-contamination matrix:
# [[1.   0.39 0.53 0.45 0.28 0.64 0.27]
#  [0.81 1.   0.68 0.72 0.49 0.98 0.25]
#  [0.64 0.38 1.   0.56 0.23 0.68 0.26]
#  [0.6  0.42 0.6  1.   0.08 0.68 0.33]
#  [0.15 0.13 0.05 0.   1.   0.01 0.  ]
#  [0.28 0.21 0.23 0.19 0.   1.   0.04]
#  [0.02 0.   0.   0.   0.   0.   1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.75 0.75 0.71 0.46 0.8  0.45]
#  [0.75 1.   0.62 0.78 0.54 0.78 0.44]
#  [0.75 0.62 1.   0.69 0.34 0.76 0.31]
#  [0.71 0.78 0.69 1.   0.36 0.77 0.4 ]
#  [0.46 0.54 0.34 0.36 1.   0.42 0.4 ]
#  [0.8  0.78 0.76 0.77 0.42 1.   0.32]
#  [0.45 0.44 0.31 0.4  0.4  0.32 1.  ]]
# Merging on 12 clusters
# MEMORY 0.512905216
# On merging iteration 1
# Numbers for each pattern pre-subsample: [304, 110, 236, 72, 65, 34, 32, 27, 14, 8, 6, 3]
# Numbers after subsampling: [300, 110, 236, 72, 65, 34, 32, 27, 14, 8, 6, 3]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 2.7583301067352295 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 1.148597002029419 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 2.31648588180542 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.8815479278564453 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.7454972267150879 s
# Computing sims for pattern 5
# Computed sims for pattern 5 in 0.5413107872009277 s
# Computing sims for pattern 6
# Computed sims for pattern 6 in 0.5048060417175293 s
# Computing sims for pattern 7
# Computed sims for pattern 7 in 0.42035889625549316 s
# Computing sims for pattern 8
# Computed sims for pattern 8 in 0.30530309677124023 s
# Computing sims for pattern 9
# Computed sims for pattern 9 in 0.20081400871276855 s
# Computing sims for pattern 10
# Computed sims for pattern 10 in 0.1685028076171875 s
# Computing sims for pattern 11
# Computed sims for pattern 11 in 0.21804594993591309 s
# Cluster sizes
# [304 110 236  72  65  34  32  27  14   8   6   3]
# Cross-contamination matrix:
# [[1.   0.62 0.47 0.7  0.37 0.3  0.54 0.33 0.33 0.7  0.42 0.2 ]
#  [0.3  1.   0.17 0.09 0.15 0.76 0.19 0.52 0.4  0.19 0.44 0.25]
#  [0.48 0.43 1.   0.42 0.68 0.6  0.54 0.38 0.39 0.27 0.43 0.04]
#  [0.68 0.28 0.38 1.   0.48 0.33 0.52 0.54 0.38 0.68 0.74 0.06]
#  [0.34 0.34 0.6  0.5  1.   0.22 0.31 0.12 0.11 0.24 0.13 0.06]
#  [0.13 0.83 0.35 0.16 0.13 1.   0.39 0.53 0.45 0.28 0.64 0.27]
#  [0.71 0.58 0.67 0.68 0.45 0.81 1.   0.68 0.72 0.49 0.98 0.25]
#  [0.22 0.68 0.26 0.34 0.1  0.64 0.38 1.   0.56 0.23 0.68 0.26]
#  [0.21 0.63 0.24 0.24 0.06 0.6  0.42 0.6  1.   0.08 0.68 0.33]
#  [0.31 0.13 0.04 0.34 0.09 0.15 0.13 0.05 0.   1.   0.01 0.  ]
#  [0.04 0.21 0.04 0.13 0.01 0.28 0.21 0.23 0.19 0.   1.   0.04]
#  [0.   0.02 0.   0.   0.   0.02 0.   0.   0.   0.   0.   1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.49 0.64 0.79 0.4  0.61 0.78 0.45 0.57 0.82 0.58 0.41]
#  [0.49 1.   0.38 0.35 0.37 0.87 0.59 0.71 0.69 0.58 0.73 0.39]
#  [0.64 0.38 1.   0.66 0.82 0.66 0.74 0.5  0.56 0.34 0.53 0.13]
#  [0.79 0.35 0.66 1.   0.45 0.58 0.77 0.57 0.54 0.65 0.67 0.11]
#  [0.4  0.37 0.82 0.45 1.   0.44 0.52 0.33 0.38 0.36 0.31 0.16]
#  [0.61 0.87 0.66 0.58 0.44 1.   0.75 0.75 0.71 0.46 0.8  0.45]
#  [0.78 0.59 0.74 0.77 0.52 0.75 1.   0.62 0.78 0.54 0.78 0.44]
#  [0.45 0.71 0.5  0.57 0.33 0.75 0.62 1.   0.69 0.34 0.76 0.31]
#  [0.57 0.69 0.56 0.54 0.38 0.71 0.78 0.69 1.   0.36 0.77 0.4 ]
#  [0.82 0.58 0.34 0.65 0.36 0.46 0.54 0.34 0.36 1.   0.42 0.4 ]
#  [0.58 0.73 0.53 0.67 0.31 0.8  0.78 0.76 0.77 0.42 1.   0.32]
#  [0.41 0.39 0.13 0.11 0.16 0.45 0.44 0.31 0.4  0.4  0.32 1.  ]]
# Collapsing 1 & 5 with crosscontam 0.7558438149113891 and sim 0.8741122255558186
# Trimming eliminated 0 seqlets out of 144
# Unmerged patterns remapping: OrderedDict([(0, 0), (2, 1), (3, 3), (4, 4), (6, 5), (7, 6), (8, 7), (9, 8), (10, 9), (11, 10)])
# Time spent on merging iteration: 0.31264805793762207
# On merging iteration 2
# Numbers for each pattern pre-subsample: [304, 236, 144, 72, 65, 32, 27, 14, 8, 6, 3]
# Numbers after subsampling: [300, 236, 144, 72, 65, 32, 27, 14, 8, 6, 3]
# Computing sims for pattern 0
# Computed sims for pattern 0 in 0.2804999351501465 s
# Computing sims for pattern 1
# Computed sims for pattern 1 in 0.23003315925598145 s
# Computing sims for pattern 2
# Computed sims for pattern 2 in 1.2659049034118652 s
# Computing sims for pattern 3
# Computed sims for pattern 3 in 0.08699417114257812 s
# Computing sims for pattern 4
# Computed sims for pattern 4 in 0.07422804832458496 s
# Computing sims for pattern 5
# Computed sims for pattern 5 in 0.05096602439880371 s
# Computing sims for pattern 6
# Computed sims for pattern 6 in 0.04444718360900879 s
# Computing sims for pattern 7
# Computed sims for pattern 7 in 0.03201007843017578 s
# Computing sims for pattern 8
# Computed sims for pattern 8 in 0.023533105850219727 s
# Computing sims for pattern 9
# Computed sims for pattern 9 in 0.020242929458618164 s
# Computing sims for pattern 10
# Computed sims for pattern 10 in 0.015546798706054688 s
# Cluster sizes
# [304 236 144  72  65  32  27  14   8   6   3]
# Cross-contamination matrix:
# [[1.   0.47 0.26 0.7  0.37 0.54 0.33 0.33 0.7  0.42 0.2 ]
#  [0.48 1.   0.47 0.42 0.68 0.54 0.38 0.39 0.27 0.43 0.04]
#  [0.13 0.28 1.   0.17 0.2  0.31 0.6  0.5  0.3  0.57 0.33]
#  [0.68 0.38 0.29 1.   0.48 0.52 0.54 0.38 0.68 0.74 0.06]
#  [0.34 0.6  0.3  0.5  1.   0.31 0.12 0.11 0.24 0.13 0.06]
#  [0.71 0.67 0.63 0.68 0.45 1.   0.68 0.72 0.49 0.98 0.25]
#  [0.22 0.26 0.67 0.34 0.1  0.38 1.   0.56 0.23 0.68 0.26]
#  [0.21 0.24 0.62 0.24 0.06 0.42 0.6  1.   0.08 0.68 0.33]
#  [0.31 0.04 0.14 0.34 0.09 0.13 0.05 0.   1.   0.01 0.  ]
#  [0.04 0.04 0.22 0.13 0.01 0.21 0.23 0.19 0.   1.   0.04]
#  [0.   0.   0.01 0.   0.   0.   0.   0.   0.   0.   1.  ]]
# Pattern-to-pattern sim matrix:
# [[1.   0.64 0.5  0.79 0.4  0.78 0.45 0.57 0.82 0.58 0.41]
#  [0.64 1.   0.46 0.66 0.82 0.74 0.5  0.56 0.34 0.53 0.13]
#  [0.5  0.46 1.   0.41 0.32 0.64 0.74 0.71 0.57 0.76 0.4 ]
#  [0.79 0.66 0.41 1.   0.45 0.77 0.57 0.54 0.65 0.67 0.11]
#  [0.4  0.82 0.32 0.45 1.   0.52 0.33 0.38 0.36 0.31 0.16]
#  [0.78 0.74 0.64 0.77 0.52 1.   0.62 0.78 0.54 0.78 0.44]
#  [0.45 0.5  0.74 0.57 0.33 0.62 1.   0.69 0.34 0.76 0.31]
#  [0.57 0.56 0.71 0.54 0.38 0.78 0.69 1.   0.36 0.77 0.4 ]
#  [0.82 0.34 0.57 0.65 0.36 0.54 0.34 0.36 1.   0.42 0.4 ]
#  [0.58 0.53 0.76 0.67 0.31 0.78 0.76 0.77 0.42 1.   0.32]
#  [0.41 0.13 0.4  0.11 0.16 0.44 0.31 0.4  0.4  0.32 1.  ]]
# Got 11 patterns after merging
# MEMORY 0.512159744
# Performing filtering
# MEMORY 0.512159744
# Got 5 patterns after filtering
# MEMORY 0.512159744
# Total time taken is 91.51s
# MEMORY 0.512159744
# Applying subclustering to the final motifs
# On pattern 0
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 304 samples in 0.004s...
# [t-SNE] Computed neighbors for 304 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 304 / 304
# [t-SNE] Mean sigma: 0.351001
# [t-SNE] Computed conditional probabilities in 0.013s
# [t-SNE] Iteration 50: error = 59.9182053, gradient norm = 0.5374723 (50 iterations in 0.043s)
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 220 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 304 out of 304 | elapsed:    0.1s finished
# [t-SNE] Iteration 100: error = 62.5681534, gradient norm = 0.4966275 (50 iterations in 0.054s)
# [t-SNE] Iteration 150: error = 62.7612686, gradient norm = 0.5227991 (50 iterations in 0.050s)
# [t-SNE] Iteration 200: error = 63.3689957, gradient norm = 0.4924805 (50 iterations in 0.050s)
# [t-SNE] Iteration 250: error = 62.7219582, gradient norm = 0.4876257 (50 iterations in 0.046s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.721958
# [t-SNE] Iteration 300: error = 1.1230352, gradient norm = 0.0059577 (50 iterations in 0.038s)
# [t-SNE] Iteration 350: error = 1.0292575, gradient norm = 0.0023572 (50 iterations in 0.042s)
# [t-SNE] Iteration 400: error = 0.9775794, gradient norm = 0.0011353 (50 iterations in 0.037s)
# [t-SNE] Iteration 450: error = 0.9636078, gradient norm = 0.0014702 (50 iterations in 0.037s)
# [t-SNE] Iteration 500: error = 0.9395132, gradient norm = 0.0010002 (50 iterations in 0.042s)
# [t-SNE] Iteration 550: error = 0.9230546, gradient norm = 0.0007232 (50 iterations in 0.036s)
# [t-SNE] Iteration 600: error = 0.9144024, gradient norm = 0.0006903 (50 iterations in 0.037s)
# [t-SNE] Iteration 650: error = 0.9115925, gradient norm = 0.0001930 (50 iterations in 0.042s)
# [t-SNE] Iteration 700: error = 0.9101504, gradient norm = 0.0002067 (50 iterations in 0.037s)
# [t-SNE] Iteration 750: error = 0.9099797, gradient norm = 0.0001780 (50 iterations in 0.038s)
# [t-SNE] Iteration 800: error = 0.9099563, gradient norm = 0.0000561 (50 iterations in 0.040s)
# [t-SNE] Iteration 850: error = 0.9098638, gradient norm = 0.0001112 (50 iterations in 0.036s)
# [t-SNE] Iteration 900: error = 0.9097512, gradient norm = 0.0001174 (50 iterations in 0.038s)
# [t-SNE] Iteration 950: error = 0.9099582, gradient norm = 0.0001091 (50 iterations in 0.043s)
# [t-SNE] Iteration 1000: error = 0.9099228, gradient norm = 0.0000805 (50 iterations in 0.037s)
# [t-SNE] KL divergence after 1000 iterations: 0.909923
# [t-SNE] Computed conditional probabilities for sample 304 / 304
# [t-SNE] Mean sigma: 0.351001
# Beginning preprocessing + Leiden
# Affmat shape: 304
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.9s
# Quality: 0.36825186997409254
# Quality: 0.36832100050697253
# Quality: 0.36841773908963404
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    4.6s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 190 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 236 out of 236 | elapsed:    0.1s finished
# Got subclusters: Counter({0: 74, 1: 60, 2: 50, 3: 46, 4: 36, 5: 25, 6: 7, 7: 6})
# On pattern 1
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 236 samples in 0.002s...
# [t-SNE] Computed neighbors for 236 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 236 / 236
# [t-SNE] Mean sigma: 0.383948
# [t-SNE] Computed conditional probabilities in 0.009s
# [t-SNE] Iteration 50: error = 62.5885544, gradient norm = 0.4672019 (50 iterations in 0.031s)
# [t-SNE] Iteration 100: error = 60.8389778, gradient norm = 0.5093389 (50 iterations in 0.035s)
# [t-SNE] Iteration 150: error = 57.8717728, gradient norm = 0.5060918 (50 iterations in 0.046s)
# [t-SNE] Iteration 200: error = 61.1356354, gradient norm = 0.4727102 (50 iterations in 0.048s)
# [t-SNE] Iteration 250: error = 62.7415314, gradient norm = 0.4676513 (50 iterations in 0.034s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 62.741531
# [t-SNE] Iteration 300: error = 0.9665679, gradient norm = 0.0056313 (50 iterations in 0.031s)
# [t-SNE] Iteration 350: error = 0.8580822, gradient norm = 0.0027066 (50 iterations in 0.030s)
# [t-SNE] Iteration 400: error = 0.7927270, gradient norm = 0.0027456 (50 iterations in 0.035s)
# [t-SNE] Iteration 450: error = 0.7768732, gradient norm = 0.0014258 (50 iterations in 0.035s)
# [t-SNE] Iteration 500: error = 0.7754449, gradient norm = 0.0002413 (50 iterations in 0.033s)
# [t-SNE] Iteration 550: error = 0.7754690, gradient norm = 0.0001415 (50 iterations in 0.030s)
# [t-SNE] Iteration 600: error = 0.7752087, gradient norm = 0.0001636 (50 iterations in 0.030s)
# [t-SNE] Iteration 650: error = 0.7756886, gradient norm = 0.0000942 (50 iterations in 0.029s)
# [t-SNE] Iteration 700: error = 0.7755752, gradient norm = 0.0001979 (50 iterations in 0.029s)
# [t-SNE] Iteration 750: error = 0.7755058, gradient norm = 0.0001785 (50 iterations in 0.034s)
# [t-SNE] Iteration 800: error = 0.7752045, gradient norm = 0.0002105 (50 iterations in 0.035s)
# [t-SNE] Iteration 850: error = 0.7756119, gradient norm = 0.0001549 (50 iterations in 0.030s)
# [t-SNE] Iteration 900: error = 0.7753302, gradient norm = 0.0001586 (50 iterations in 0.030s)
# [t-SNE] Iteration 950: error = 0.7750942, gradient norm = 0.0001342 (50 iterations in 0.030s)
# [t-SNE] Iteration 1000: error = 0.7751637, gradient norm = 0.0001564 (50 iterations in 0.030s)
# [t-SNE] KL divergence after 1000 iterations: 0.775164
# [t-SNE] Computed conditional probabilities for sample 236 / 236
# [t-SNE] Mean sigma: 0.383948
# Beginning preprocessing + Leiden
# Affmat shape: 236
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.5s
# Quality: 0.36217916769651154
# Quality: 0.3632638688369948
# Quality: 0.3640579831824684
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    4.1s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done 130 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 144 out of 144 | elapsed:    0.1s finished
# Got subclusters: Counter({0: 63, 1: 48, 2: 47, 3: 46, 4: 32})
# On pattern 2
# [t-SNE] Computing 143 nearest neighbors...
# [t-SNE] Indexed 144 samples in 0.002s...
# [t-SNE] Computed neighbors for 144 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 144 / 144
# [t-SNE] Mean sigma: 0.392899
# [t-SNE] Computed conditional probabilities in 0.005s
# [t-SNE] Iteration 50: error = 55.2705078, gradient norm = 0.5292356 (50 iterations in 0.019s)
# [t-SNE] Iteration 100: error = 55.0460968, gradient norm = 0.5923546 (50 iterations in 0.020s)
# [t-SNE] Iteration 150: error = 53.5904465, gradient norm = 0.5118738 (50 iterations in 0.020s)
# [t-SNE] Iteration 200: error = 55.4470215, gradient norm = 0.5244130 (50 iterations in 0.020s)
# [t-SNE] Iteration 250: error = 54.1911354, gradient norm = 0.5711983 (50 iterations in 0.020s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.191135
# [t-SNE] Iteration 300: error = 0.6855047, gradient norm = 0.0066869 (50 iterations in 0.031s)
# [t-SNE] Iteration 350: error = 0.4911518, gradient norm = 0.0024787 (50 iterations in 0.025s)
# [t-SNE] Iteration 400: error = 0.4903719, gradient norm = 0.0003476 (50 iterations in 0.021s)
# [t-SNE] Iteration 450: error = 0.4901907, gradient norm = 0.0007112 (50 iterations in 0.019s)
# [t-SNE] Iteration 500: error = 0.4899858, gradient norm = 0.0001870 (50 iterations in 0.019s)
# [t-SNE] Iteration 550: error = 0.4899327, gradient norm = 0.0001035 (50 iterations in 0.019s)
# [t-SNE] Iteration 600: error = 0.4899669, gradient norm = 0.0001770 (50 iterations in 0.019s)
# [t-SNE] Iteration 650: error = 0.4899527, gradient norm = 0.0000936 (50 iterations in 0.019s)
# [t-SNE] Iteration 700: error = 0.4899874, gradient norm = 0.0001083 (50 iterations in 0.019s)
# [t-SNE] Iteration 750: error = 0.4899435, gradient norm = 0.0000766 (50 iterations in 0.019s)
# [t-SNE] Iteration 800: error = 0.4899793, gradient norm = 0.0001146 (50 iterations in 0.019s)
# [t-SNE] Iteration 850: error = 0.4899811, gradient norm = 0.0000867 (50 iterations in 0.024s)
# [t-SNE] Iteration 900: error = 0.4899539, gradient norm = 0.0000906 (50 iterations in 0.023s)
# [t-SNE] Iteration 900: did not make any progress during the last 300 episodes. Finished.
# [t-SNE] KL divergence after 900 iterations: 0.489954
# [t-SNE] Computed conditional probabilities for sample 144 / 144
# [t-SNE] Mean sigma: 0.392899
# Beginning preprocessing + Leiden
# Affmat shape: 144
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    3.3s
# Quality: 0.26129002656998984
# Quality: 0.2645042443639123
# Quality: 0.2665226116204713
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.8s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  72 out of  72 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 42, 1: 39, 2: 25, 3: 18, 4: 17, 5: 3})
# On pattern 3
# [t-SNE] Computing 71 nearest neighbors...
# [t-SNE] Indexed 72 samples in 0.001s...
# [t-SNE] Computed neighbors for 72 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 72 / 72
# [t-SNE] Mean sigma: 0.618983
# [t-SNE] Computed conditional probabilities in 0.002s
# [t-SNE] Iteration 50: error = 43.6313553, gradient norm = 0.6077244 (50 iterations in 0.013s)
# [t-SNE] Iteration 100: error = 48.0792160, gradient norm = 0.5260203 (50 iterations in 0.025s)
# [t-SNE] Iteration 150: error = 47.9000778, gradient norm = 0.3913471 (50 iterations in 0.014s)
# [t-SNE] Iteration 200: error = 49.0026131, gradient norm = 0.4676682 (50 iterations in 0.015s)
# [t-SNE] Iteration 250: error = 49.0325089, gradient norm = 0.5351155 (50 iterations in 0.027s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 49.032509
# [t-SNE] Iteration 300: error = 0.8269839, gradient norm = 0.0027631 (50 iterations in 0.012s)
# [t-SNE] Iteration 350: error = 0.7044594, gradient norm = 0.0021467 (50 iterations in 0.013s)
# [t-SNE] Iteration 400: error = 0.6215044, gradient norm = 0.0018129 (50 iterations in 0.026s)
# [t-SNE] Iteration 450: error = 0.5413714, gradient norm = 0.0012478 (50 iterations in 0.020s)
# [t-SNE] Iteration 500: error = 0.4690557, gradient norm = 0.0030308 (50 iterations in 0.024s)
# [t-SNE] Iteration 550: error = 0.4097880, gradient norm = 0.0010214 (50 iterations in 0.013s)
# [t-SNE] Iteration 600: error = 0.3475902, gradient norm = 0.0033113 (50 iterations in 0.013s)
# [t-SNE] Iteration 650: error = 0.1201840, gradient norm = 0.0153912 (50 iterations in 0.023s)
# [t-SNE] Iteration 700: error = 0.1074509, gradient norm = 0.0020579 (50 iterations in 0.013s)
# [t-SNE] Iteration 750: error = 0.1075912, gradient norm = 0.0011462 (50 iterations in 0.012s)
# [t-SNE] Iteration 800: error = 0.1077306, gradient norm = 0.0011282 (50 iterations in 0.023s)
# [t-SNE] Iteration 850: error = 0.1077476, gradient norm = 0.0007029 (50 iterations in 0.012s)
# [t-SNE] Iteration 900: error = 0.1076915, gradient norm = 0.0007273 (50 iterations in 0.012s)
# [t-SNE] Iteration 950: error = 0.1078136, gradient norm = 0.0010384 (50 iterations in 0.020s)
# [t-SNE] Iteration 1000: error = 0.1079696, gradient norm = 0.0007934 (50 iterations in 0.026s)
# [t-SNE] KL divergence after 1000 iterations: 0.107970
# [t-SNE] Computed conditional probabilities for sample 72 / 72
# [t-SNE] Mean sigma: 0.618983
# Beginning preprocessing + Leiden
# Affmat shape: 72
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.9s
# Quality: 0.19819988581663242
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.3s finished
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  65 out of  65 | elapsed:    0.0s finished
# Got subclusters: Counter({0: 30, 1: 28, 2: 12, 3: 2})
# On pattern 4
# [t-SNE] Computing 64 nearest neighbors...
# [t-SNE] Indexed 65 samples in 0.001s...
# [t-SNE] Computed neighbors for 65 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 65 / 65
# [t-SNE] Mean sigma: 0.663488
# [t-SNE] Computed conditional probabilities in 0.001s
# [t-SNE] Iteration 50: error = 46.7836304, gradient norm = 0.5167156 (50 iterations in 0.017s)
# [t-SNE] Iteration 100: error = 47.4263916, gradient norm = 0.4445778 (50 iterations in 0.013s)
# [t-SNE] Iteration 150: error = 48.6263046, gradient norm = 0.4614816 (50 iterations in 0.019s)
# [t-SNE] Iteration 200: error = 47.2244263, gradient norm = 0.6150818 (50 iterations in 0.018s)
# [t-SNE] Iteration 250: error = 44.2807732, gradient norm = 0.6892756 (50 iterations in 0.013s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 44.280773
# [t-SNE] Iteration 300: error = 0.9665012, gradient norm = 0.0022504 (50 iterations in 0.017s)
# [t-SNE] Iteration 350: error = 0.8127874, gradient norm = 0.0006322 (50 iterations in 0.019s)
# [t-SNE] Iteration 400: error = 0.7462968, gradient norm = 0.0006045 (50 iterations in 0.012s)
# [t-SNE] Iteration 450: error = 0.7080864, gradient norm = 0.0003801 (50 iterations in 0.019s)
# [t-SNE] Iteration 500: error = 0.6916207, gradient norm = 0.0001898 (50 iterations in 0.026s)
# [t-SNE] Iteration 550: error = 0.6804342, gradient norm = 0.0001924 (50 iterations in 0.015s)
# [t-SNE] Iteration 600: error = 0.6738378, gradient norm = 0.0001602 (50 iterations in 0.023s)
# [t-SNE] Iteration 650: error = 0.6647249, gradient norm = 0.0001634 (50 iterations in 0.012s)
# [t-SNE] Iteration 700: error = 0.6535268, gradient norm = 0.0002743 (50 iterations in 0.012s)
# [t-SNE] Iteration 750: error = 0.6433277, gradient norm = 0.0003302 (50 iterations in 0.031s)
# [t-SNE] Iteration 800: error = 0.6311283, gradient norm = 0.0002800 (50 iterations in 0.015s)
# [t-SNE] Iteration 850: error = 0.6226790, gradient norm = 0.0001345 (50 iterations in 0.024s)
# [t-SNE] Iteration 900: error = 0.6110688, gradient norm = 0.0002078 (50 iterations in 0.013s)
# [t-SNE] Iteration 950: error = 0.5965673, gradient norm = 0.0004606 (50 iterations in 0.012s)
# [t-SNE] Iteration 1000: error = 0.5780830, gradient norm = 0.0002787 (50 iterations in 0.020s)
# [t-SNE] KL divergence after 1000 iterations: 0.578083
# [t-SNE] Computed conditional probabilities for sample 65 / 65
# [t-SNE] Mean sigma: 0.663488
# Beginning preprocessing + Leiden
# Affmat shape: 65
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    2.9s
# Quality: 0.14677659491596115
# Got subclusters: Counter({0: 32, 1: 24, 2: 9})
# [Parallel(n_jobs=4)]: Done  50 out of  50 | elapsed:    3.3s finished

# %%
import h5py
import modisco.util
reload(modisco.util)
![[ -e ../results/Tm/results.hdf5 ]] && rm ../results/Tm/results.hdf5
grp = h5py.File("../results/Um/results.hdf5", "w")
tfmodisco_results.save_hdf5(grp)
grp.close()

# %%
from collections import Counter
from modisco.visualization import viz_sequence
reload(viz_sequence)
from matplotlib import pyplot as plt

import modisco.affinitymat.core
reload(modisco.affinitymat.core)
import modisco.cluster.phenograph.core
reload(modisco.cluster.phenograph.core)
import modisco.cluster.phenograph.cluster
reload(modisco.cluster.phenograph.cluster)
import modisco.cluster.core
reload(modisco.cluster.core)
import modisco.aggregator
reload(modisco.aggregator)

hdf5_results = h5py.File("../results/Um/results.hdf5","r")

print("Metaclusters heatmap")
import seaborn as sns
activity_patterns = np.array(hdf5_results['metaclustering_results']['attribute_vectors'])[
                    np.array(
        [x[0] for x in sorted(
                enumerate(hdf5_results['metaclustering_results']['metacluster_indices']),
               key=lambda x: x[1])])]
sns.heatmap(activity_patterns, center=0)
plt.show()

metacluster_names = [
    x.decode("utf-8") for x in 
    list(hdf5_results["metaclustering_results"]
         ["all_metacluster_names"][:])]

all_patterns = []
background = np.array([0.2674, 0.2082, 0.2190, 0.3054])

for metacluster_name in metacluster_names:
    print(metacluster_name)
    metacluster_grp = (hdf5_results["metacluster_idx_to_submetacluster_results"]
                                   [metacluster_name])
    print("activity pattern:",metacluster_grp["activity_pattern"][:])
    all_pattern_names = [x.decode("utf-8") for x in 
                         list(metacluster_grp["seqlets_to_patterns_result"]
                                             ["patterns"]["all_pattern_names"][:])]
    if (len(all_pattern_names)==0):
        print("No motifs found for this activity pattern")
    for pattern_name in all_pattern_names:
        print(metacluster_name, pattern_name)
        all_patterns.append((metacluster_name, pattern_name))
        pattern = metacluster_grp["seqlets_to_patterns_result"]["patterns"][pattern_name]
        print("total seqlets:",len(pattern["seqlets_and_alnmts"]["seqlets"]))
        
        print("onehot, fwd and rev:")
        viz_sequence.plot_weights(viz_sequence.ic_scale(np.array(pattern["sequence"]["fwd"]),
                                                        background=background)) 
        
hdf5_results.close()
# Out:
# Metaclusters heatmap
# metacluster_0
# activity pattern: [1]
# metacluster_0 pattern_0
# total seqlets: 304
# onehot, fwd and rev:
# metacluster_0 pattern_1
# total seqlets: 236
# onehot, fwd and rev:
# metacluster_0 pattern_2
# total seqlets: 144
# onehot, fwd and rev:
# metacluster_0 pattern_3
# total seqlets: 72
# onehot, fwd and rev:
# metacluster_0 pattern_4
# total seqlets: 65
# onehot, fwd and rev:
